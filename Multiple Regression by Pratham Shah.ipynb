# %% [markdown]
# # Multiple Linear Regression to Predict the prices of cars:
#
# Implemented by Pratham Shah (240962070) as part of the Project MANAS '24-25 Taskphase

# %% [markdown]
# ## Step 1: Imports and Cleaning the training/testing data.

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#reading the training and testing data
do = pd.read_csv("Train.csv")
test_do = pd.read_csv("Test.csv")

#tdata and testdata are lists of data (all feature's numeric values for a particular row in the dataset)
tdata = []
data = []

#exclues sr no and price. needed_titles are used to fill up tdata/data.
needed_titles = list(do)[1:-1]

#training prices = prices, testing prices = tprices
prices = do['Price']
tprices = test_do['Price']

#test_df and df are copies of test_do and do. I'm modifying these without touching test_do and do.
test_df = test_do.copy()
df = do.copy()

#To implement one hot encoding using pandas, for the names of the cars, im using only the brand names of the cars. This code does that.
for index, name in enumerate(df["Name"]):
    df.loc[index, "Name"] = str(df.loc[index, "Name"]).lower().split(" ")[0]
for index, name in enumerate(test_df["Name"]):
    test_df.loc[index, "Name"] = str(test_df.loc[index, "Name"]).lower().split(" ")[0]

#implementing one hot encoding using pandas.get_dummies for the columns where one hot encoding is needed
test_df = pd.get_dummies(test_df[needed_titles], columns = ["Name", "Location", "Fuel_Type" , "Transmission", "Owner_Type", "Year"], dtype=int)
df = pd.get_dummies(df[needed_titles], columns = ["Name", "Location", "Fuel_Type" , "Transmission", "Owner_Type", "Year"], dtype=int)

#This converts all numeric data stored as strings in the dataset into corresponding numbers only (eg. "80 kmpl" -> 80). null values converted to -1, to be removed later (eg. "null bhp" -> -1).
for index, vals in df.iterrows():
    df = df.replace(df["Engine"][index], float(str(df["Engine"][index]).replace(" CC", ""))).replace(df["Mileage"][index], float(str(df["Mileage"][index]).replace(" kmpl", "").replace("nan", "0"))).replace(df["Power"][index], float(str(df["Power"][index]).replace(" bhp", "").replace("null", "-1")))
    df.infer_objects(copy=False)

for tindex, tvals in test_df.iterrows():
    test_df = test_df.replace(test_df["Engine"][tindex], float(str(test_df["Engine"][tindex]).replace(" CC", ""))).replace(test_df["Mileage"][tindex], float(str(test_df["Mileage"][tindex]).replace(" kmpl", "").replace("nan", "0"))).replace(test_df["Power"][tindex], float(str(test_df["Power"][tindex]).replace(" bhp", "").replace("null", "-1")))
    test_df.infer_objects(copy=False)

#one hot encoding creates multiple new columns, depending on unique values in the dataset.
#training and testing datasets may not have exactly the same number of unique values.
#this adds missing columns to the datasets, so that they can have exactly the same no. of columns.
test_df_titles = list(test_df) #titles of testing dataframe
df_titles = list(df) #titles of training dataframe
for index, value in enumerate(df_titles):
    if test_df_titles.count(value) == 0:
        test_df.insert(index, value, list(0 for val in range(0, len(test_df))), True)
for index, value in enumerate(test_df_titles):
    if df_titles.count(value) == 0:
        df.insert(index, value, list(0 for val in range(0, len(df))), True)

#Above, I converted all null values to -1. This code removes all training/testing examples containing such a -1 from df/test_df
#The goal is to ensure that no 'null' valued training example is used to train the model.
for index, value in df.iterrows():
    if(df["Power"][index] == -1):
        df.drop(index, inplace=True)
        prices.drop(index=index, inplace=True)
for index, value in test_df.iterrows():
    if(test_df["Power"][index] == -1):
        test_df.drop(index, inplace=True)
        tprices.drop(index=index, inplace=True)

#data and tdata store the df and test_df's feature values for all the training examples as a list.
#this is a 2D list (mxn) where m = valid training examples and n = no. of columns in the feature dataset.
#data can be visualised as [[0, 0, 1, 0, 89.5, .. n features numerical values], [n numerical values], .... m valid training examples]
data = df.values.tolist()
tdata = test_df.values.tolist()

#checks if the data is organised enough to perform multiple regression.
#checks if the training and testing dataframes have the same number of feature columns
#checks if all features dataframes have a corresponding price
if len(data[0]) == len(tdata[0]) and len(prices) == len(data):
    print(f"PARSING SUCESSFUL ({len(data[0])} feature columns)  " * 3)
    if(len(do)-len(df) != 0):
        print(f"CAUTION: {len(do) - len(df)} examples dropped from training set, {len(test_do)-len(test_df)} examples dropped from testing set. (null value encountered)")
else:
    print(" WARNING: PARSING FAILURE " * 5)
# Out:
# /tmp/ipykernel_36407/982559814.py:37: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(df["Engine"][index], float(str(df["Engine"][index]).replace(" CC", ""))).replace(df["Mileage"][index], float(str(df["Mileage"][index]).replace(" kmpl", "").replace("nan", "0"))).replace(df["Power"][index], float(str(df["Power"][index]).replace(" bhp", "").replace("null", "-1")))
# PARSING SUCESSFUL (75 feature columns)  PARSING SUCESSFUL (75 feature columns)  PARSING SUCESSFUL (75 feature columns)
# CAUTION: 70 examples dropped from training set, 19 examples dropped from testing set. (null value encountered)
# /tmp/ipykernel_36407/982559814.py:41: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df = test_df.replace(test_df["Engine"][tindex], float(str(test_df["Engine"][tindex]).replace(" CC", ""))).replace(test_df["Mileage"][tindex], float(str(test_df["Mileage"][tindex]).replace(" kmpl", "").replace("nan", "0"))).replace(test_df["Power"][tindex], float(str(test_df["Power"][tindex]).replace(" bhp", "").replace("null", "-1")))

# %% [markdown]
# ## Step 2: Defining the functions to use for Multiple Linear Regression.

# %%
def z_score_normalise(X):
    #Z score normalisation algorithm. Returns z score normalised dataset, means and std. deviations of the features.
    # find the mean of each n columns
    means     = np.mean(X, axis=0)                 # mean will have length n
    # find the standard deviation of each n columns
    stdevs  = np.std(X, axis=0)+0.00001                 # sigma will have length n. +0.00001 to prevent divide by 0 error.
    X_norm = (X - means) / stdevs    

    return (X_norm, means, stdevs)

def get_predictions(testing, weights, bias, correctvals):
  #returns predictions and their corresponding errors.
  #predict output value using test data multiplied by corresponding weights, + bias
  predictions = [np.dot(val, weights) + bias for val in testing]
  i = 0
  errs = []
  r2_numerator = 0
  r2_denominator = 0
  #mean of the correct values, for calculating r2 score.
  correct_avg = sum(correctvals)/len(correctvals)
  for value in predictions:
    #append error in prediction
    errs.append(value - correctvals[i])
    r2_numerator += math.pow(correctvals[i] - value,2) #calculates r2 numerator
    r2_denominator += math.pow(correctvals[i]- correct_avg, 2) #calculates r2 denominator
    i += 1 #looping variable
  mse = sum([err*err for err in errs])/len(errs) #mean squared error
  rmse = math.sqrt(mse) #root mean squared error
  return predictions, mse, rmse, 1 - r2_numerator/r2_denominator

def calculate_cost(X, y, w, b):
    m = X.shape[0] #stores number of training examples (m), to iterate through them
    cost = 0.0
    for i in range(m):                                      #iterates through training examples                            
        value_using_given_params = np.dot(X[i], w) + b      #stores the predicted value of the data, using provided weights and bias
        cost = cost + (value_using_given_params - y[i])**2  #calculates the 'sigma' part of the cost function 
    cost = cost / (2 * m)                                   #1/2m * sigma part = complete cost value          
    return cost

def calculate_gradient(X, y, w, b):
    m,n = X.shape           #(number of examples, number of features)
    dj_dw = np.zeros((n,))
    dj_db = 0.
    for i in range(m):                             
        err = (np.dot(X[i], w) + b) - y[i] #calculates error between actual and predicted value
        for j in range(n):                          
            dj_dw[j] = dj_dw[j] + err * X[i, j]    
        dj_db = dj_db + err                        
    dj_dw = dj_dw / m                                
    dj_db = dj_db / m                                
    return dj_db, dj_dw #returns derivate of cost function wrt bias and weights

def gradient_descent(X, y, w_init, b_init, cost_function, gradient_function, alpha, num_iters):
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    errors = []
    w = w_init
    b = b_init
    for i in range(num_iters):
        # Calculate the gradient and update the parameters
        dj_db,dj_dw = gradient_function(X, y, w, b)

        # Update Parameters using w, b, learning rate and gradient
        w = w - alpha * dj_dw            
        b = b - alpha * dj_db          
      
        # Save cost J at each iteration
        J_history.append( cost_function(X, y, w, b))

        if(i%100 == 0):
          predictions, mse, rmse, r2 = get_predictions(X_test, w, b, y_test)
          errors.append([mse, rmse, r2])
          print(f"At iteration {i} :\nCost Function:  {cost_function(X, y, w, b)}\nMSE: {mse}\nRMSE:  {rmse}\nR2:  {r2}\n")
        
    return w, b, J_history, errors #return final w,b and J history for graphing

def multiple_regression(xvals, yvals, initial_coeffs, initial_affine, iterations, learning_rate):
  w_final, b_final, J_hist, errhist = gradient_descent(xvals, yvals, initial_coeffs, initial_affine,
                                                      calculate_cost, calculate_gradient, 
                                                      learning_rate, iterations) #gets the final weights, bias and cost function history
  for index, value in enumerate(w_final):
     print(f"Weight of {list(df)[index]}  :   {value}")
  print(f"Bias value : {b_final}") #prints the weights and bias 
  return w_final, b_final, J_hist, errhist

# %% [markdown]
# ## Step 3: Get the values and run the model.

# %%
X_train, feature_means, feature_stddevs = z_score_normalise(np.array(data)) #Z-score-normalise the training set, storing the features means and std devs for future reference.
y_train = np.array(prices) #stores training data's corresponding prices

y_test = np.array(tprices) #stores testing data prices
test_names = test_do["Name"] #stores names of cars in the testing data

b_init = 0
w_init = np.zeros_like(data[0]) #definind initial weights and biases
X_test = z_score_normalise(np.array(tdata))[0]

coeffs, affine, hist, errs = multiple_regression(X_train, y_train, np.zeros_like(w_init), 0, 7000, 0.001) #stores final weights, bias and cost function history
# Out:
# At iteration 0 :
# Cost Function:  109.16476032787602
# MSE: 220.02786878434105
# RMSE:  14.83333640096998
# R2:  -0.7705468291085651
#
# At iteration 100 :
# Cost Function:  76.78605463978911
# MSE: 156.81925588920734
# RMSE:  12.522749533916556
# R2:  -0.2619121286401378
#
# At iteration 200 :
# Cost Function:  59.310838440933296
# MSE: 122.74296152919113
# RMSE:  11.07894225678567
# R2:  0.012297112490277762
#
# At iteration 300 :
# Cost Function:  48.7109545649308
# MSE: 102.04576862313748
# RMSE:  10.101770568723953
# R2:  0.1788457841368648
#
# At iteration 400 :
# Cost Function:  41.5679436553449
# MSE: 88.04761407250999
# RMSE:  9.383369015045181
# R2:  0.2914878248470687
#
# At iteration 500 :
# Cost Function:  36.36099408286645
# MSE: 77.79245482125476
# RMSE:  8.820003107780336
# R2:  0.3740102789099674
#
# At iteration 600 :
# Cost Function:  32.36636359285983
# MSE: 69.8818306783957
# RMSE:  8.35953531474063
# R2:  0.43766644469384275
#
# At iteration 700 :
# Cost Function:  29.206326479463545
# MSE: 63.589576221922876
# RMSE:  7.974307256553567
# R2:  0.4882997178214924
#
# At iteration 800 :
# Cost Function:  26.661352849388493
# MSE: 58.49473788212094
# RMSE:  7.6481852672461414
# R2:  0.5292974783197255
#
# At iteration 900 :
# Cost Function:  24.589874331757855
# MSE: 54.325684522485396
# RMSE:  7.37059594079647
# R2:  0.562845520424892
#
# At iteration 1000 :
# Cost Function:  22.892607199621892
# MSE: 50.89132121287238
# RMSE:  7.133815333527521
# R2:  0.5904815699009793
#
# At iteration 1100 :
# Cost Function:  21.495714398083173
# MSE: 48.04891294857782
# RMSE:  6.93173231945506
# R2:  0.6133542040231206
#
# At iteration 1200 :
# Cost Function:  20.342190472778874
# MSE: 45.68776061472843
# RMSE:  6.759272195638258
# R2:  0.63235420979892
#
# At iteration 1300 :
# Cost Function:  19.387009984726173
# MSE: 43.72006043530211
# RMSE:  6.612114671971601
# R2:  0.6481881372580564
#
# At iteration 1400 :
# Cost Function:  18.594116224457338
# MSE: 42.07523847816194
# RMSE:  6.486542875689788
# R2:  0.661423889241443
#
# At iteration 1500 :
# Cost Function:  17.93438816659057
# MSE: 40.69611528759386
# RMSE:  6.379350694827324
# R2:  0.6725215842993527
#
# At iteration 1600 :
# Cost Function:  17.384177759936712
# MSE: 39.53613182798392
# RMSE:  6.28777638183674
# R2:  0.6818558793028815
#
# At iteration 1700 :
# Cost Function:  16.924210458183193
# MSE: 38.55725119014537
# RMSE:  6.20944854154903
# R2:  0.6897328542469034
#
# At iteration 1800 :
# Cost Function:  16.538734786010437
# MSE: 37.728325479982416
# RMSE:  6.1423387630431465
# R2:  0.696403153767616
#
# At iteration 1900 :
# Cost Function:  16.21485232077473
# MSE: 37.023801939438926
# RMSE:  6.084718723116043
# R2:  0.7020723988847617
#
# At iteration 2000 :
# Cost Function:  15.941983499347602
# MSE: 36.422686368247284
# RMSE:  6.035121073205349
# R2:  0.7069095282646964
#
# At iteration 2100 :
# Cost Function:  15.711438359009172
# MSE: 35.907706775620035
# RMSE:  5.992303962218542
# R2:  0.7110535282489688
#
# At iteration 2200 :
# Cost Function:  15.516069756730163
# MSE: 35.46463544576404
# RMSE:  5.955219176971074
# R2:  0.7146188881394214
#
# At iteration 2300 :
# Cost Function:  15.349992172308458
# MSE: 35.08173768228437
# RMSE:  5.9229838495714615
# R2:  0.7177000361083006
#
# At iteration 2400 :
# Cost Function:  15.208353076447226
# MSE: 34.74932257023067
# RMSE:  5.894855602152666
# R2:  0.7203749541804805
#
# At iteration 2500 :
# Cost Function:  15.087146663171083
# MSE: 34.45937628601147
# RMSE:  5.8702109234687185
# R2:  0.7227081289595321
#
# At iteration 2600 :
# Cost Function:  14.983061860808442
# MSE: 34.20526241992423
# RMSE:  5.848526516989064
# R2:  0.7247529631085838
#
# At iteration 2700 :
# Cost Function:  14.893358159286755
# MSE: 33.981476825695246
# RMSE:  5.829363329360699
# R2:  0.7265537480566517
#
# At iteration 2800 :
# Cost Function:  14.815764058524204
# MSE: 33.78344691227826
# RMSE:  5.812352958336087
# R2:  0.7281472790816363
#
# At iteration 2900 :
# Cost Function:  14.748393943372296
# MSE: 33.60736720383734
# RMSE:  5.797186145349944
# R2:  0.7295641785461128
#
# At iteration 3000 :
# Cost Function:  14.689679987761561
# MSE: 33.45006452594548
# RMSE:  5.783603074723012
# R2:  0.7308299807333107
#
# At iteration 3100 :
# Cost Function:  14.638316329844598
# MSE: 33.30888741117486
# RMSE:  5.771385224638436
# R2:  0.7319660217915678
#
# At iteration 3200 :
# Cost Function:  14.593213274781977
# MSE: 33.181615316772536
# RMSE:  5.760348541257945
# R2:  0.7329901702525017
#
# At iteration 3300 :
# Cost Function:  14.553459697995304
# MSE: 33.06638405820319
# RMSE:  5.750337734272935
# R2:  0.733917427061384
#
# At iteration 3400 :
# Cost Function:  14.518292159032379
# MSE: 32.961624521815295
# RMSE:  5.741221518267284
# R2:  0.7347604187514606
#
# At iteration 3500 :
# Cost Function:  14.48706951013507
# MSE: 32.866012256908135
# RMSE:  5.732888648570468
# R2:  0.7355298030725949
#
# At iteration 3600 :
# Cost Function:  14.459252006439549
# MSE: 32.778425985250884
# RMSE:  5.725244622306621
# R2:  0.7362346028618805
#
# At iteration 3700 :
# Cost Function:  14.434384106214535
# MSE: 32.69791342329025
# RMSE:  5.718208934910498
# R2:  0.7368824810696295
#
# At iteration 3800 :
# Cost Function:  14.412080297487273
# MSE: 32.62366310390385
# RMSE:  5.711712799494023
# R2:  0.7374799675074895
#
# At iteration 3900 :
# Cost Function:  14.39201340811045
# MSE: 32.55498112278382
# RMSE:  5.7056972512379085
# R2:  0.7380326459684536
#
# At iteration 4000 :
# Cost Function:  14.373904954863331
# MSE: 32.491271929223885
# RMSE:  5.700111571646987
# R2:  0.738545308801875
#
# At iteration 4100 :
# Cost Function:  14.357517167676725
# MSE: 32.43202244025835
# RMSE:  5.694911978271337
# R2:  0.7390220847457307
#
# At iteration 4200 :
# Cost Function:  14.34264639085963
# MSE: 32.37678888728355
# RMSE:  5.690060534588675
# R2:  0.7394665447708186
#
# At iteration 4300 :
# Cost Function:  14.329117616993484
# MSE: 32.325185910793905
# RMSE:  5.685524242389079
# R2:  0.7398817898345512
#
# At iteration 4400 :
# Cost Function:  14.316779953159765
# MSE: 32.27687750601896
# RMSE:  5.6812742854063085
# R2:  0.7402705237406975
#
# At iteration 4500 :
# Cost Function:  14.30550285516922
# MSE: 32.231569493593845
# RMSE:  5.677285398286213
# R2:  0.7406351137273011
#
# At iteration 4600 :
# Cost Function:  14.295172994931264
# MSE: 32.18900324780964
# RMSE:  5.673535339434279
# R2:  0.7409776409349529
#
# At iteration 4700 :
# Cost Function:  14.28569165023522
# MSE: 32.14895046283407
# RMSE:  5.6700044499836215
# R2:  0.7412999425225985
#
# At iteration 4800 :
# Cost Function:  14.27697252598256
# MSE: 32.11120877649317
# RMSE:  5.6666752841938255
# R2:  0.7416036468826201
#
# At iteration 4900 :
# Cost Function:  14.268939932108587
# MSE: 32.07559810332265
# RMSE:  5.663532299132993
# R2:  0.7418902031484825
#
# At iteration 5000 :
# Cost Function:  14.261527256708272
# MSE: 32.041957554935664
# RMSE:  5.660561593599672
# R2:  0.7421609059762885
#
# At iteration 5100 :
# Cost Function:  14.254675683772767
# MSE: 32.01014284734145
# RMSE:  5.657750687980291
# R2:  0.7424169164078814
#
# At iteration 5200 :
# Cost Function:  14.24833311387196
# MSE: 31.980024112568486
# RMSE:  5.655088338175496
# R2:  0.7426592794805398
#
# At iteration 5300 :
# Cost Function:  14.24245325345116
# MSE: 31.95148404647734
# RMSE:  5.652564377915332
# R2:  0.7428889391313804
#
# At iteration 5400 :
# Cost Function:  14.236994844427564
# MSE: 31.924416336586752
# RMSE:  5.6501695847635185
# R2:  0.7431067508485178
#
# At iteration 5500 :
# Cost Function:  14.231921010716237
# MSE: 31.898724323533038
# RMSE:  5.64789556591949
# R2:  0.7433134924421941
#
# At iteration 5600 :
# Cost Function:  14.227198702377127
# MSE: 31.87431985784118
# RMSE:  5.645734660594774
# R2:  0.7435098732442513
#
# At iteration 5700 :
# Cost Function:  14.2227982214161
# MSE: 31.851122320305365
# RMSE:  5.64367985629105
# R2:  0.7436965419910518
#
# At iteration 5800 :
# Cost Function:  14.218692816020194
# MSE: 31.829057779723488
# RMSE:  5.6417247167620195
# R2:  0.7438740936011221
#
# At iteration 5900 :
# Cost Function:  14.214858332270122
# MSE: 31.808058266215575
# RMSE:  5.639863319816853
# R2:  0.7440430750227014
#
# At iteration 6000 :
# Cost Function:  14.211272914236268
# MSE: 31.788061142047
# RMSE:  5.638090203432985
# R2:  0.7442039902966783
#
# At iteration 6100 :
# Cost Function:  14.207916744900581
# MSE: 31.76900855492312
# RMSE:  5.636400318902404
# R2:  0.7443573049558843
#
# At iteration 6200 :
# Cost Function:  14.204771821614417
# MSE: 31.750846961232515
# RMSE:  5.634788989947407
# R2:  0.7445034498615188
#
# At iteration 6300 :
# Cost Function:  14.201821760848363
# MSE: 31.733526708790194
# RMSE:  5.6332518769171145
# R2:  0.744642824560781
#
# At iteration 6400 :
# Cost Function:  14.199051627855104
# MSE: 31.717001670345734
# RMSE:  5.631784945321131
# R2:  0.7447758002360007
#
# At iteration 6500 :
# Cost Function:  14.19644778758162
# MSE: 31.701228920539414
# RMSE:  5.6303844380769785
# R2:  0.7449027223041468
#
# At iteration 6600 :
# Cost Function:  14.193997773759696
# MSE: 31.68616845016464
# RMSE:  5.629046850947738
# R2:  0.7450239127161353
#
# At iteration 6700 :
# Cost Function:  14.191690173595067
# MSE: 31.67178291256771
# RMSE:  5.627768910728985
# R2:  0.74513967199753
#
# At iteration 6800 :
# Cost Function:  14.189514525882599
# MSE: 31.6580373978277
# RMSE:  5.626547555813218
# R2:  0.7452502810656987
#
# At iteration 6900 :
# Cost Function:  14.187461230714996
# MSE: 31.644899231029477
# RMSE:  5.625379918816993
# R2:  0.7453560028530951
#
# Weight of Kilometers_Driven  :   -0.6624327789635619
# Weight of Mileage  :   -0.8795400731972937
# Weight of Engine  :   1.6912070465964724
# Weight of Power  :   3.5182699347807613
# Weight of Seats  :   -0.7420603877815507
# Weight of Name_ambassador  :   0.0016601080499667605
# Weight of Name_audi  :   1.3731240351742229
# Weight of Name_bmw  :   1.4069818851458682
# Weight of Name_chevrolet  :   -0.24393866483975662
# Weight of Name_datsun  :   -0.20093702003318023
# Weight of Name_fiat  :   -0.12443054166625099
# Weight of Name_force  :   -0.025311691197780487
# Weight of Name_ford  :   -0.44116287321296527
# Weight of Name_honda  :   -0.7841885136410989
# Weight of Name_hyundai  :   -0.7918572177144645
# Weight of Name_isuzu  :   -0.048467031689837535
# Weight of Name_jaguar  :   0.9091617880668458
# Weight of Name_jeep  :   -0.12617716043056176
# Weight of Name_land  :   2.084456165164296
# Weight of Name_mahindra  :   -0.7740204850036961
# Weight of Name_maruti  :   -0.35457154432097326
# Weight of Name_mercedes-benz  :   1.860868359338263
# Weight of Name_mini  :   0.8949704116723105
# Weight of Name_mitsubishi  :   -0.13933430101244318
# Weight of Name_nissan  :   -0.2583528849960763
# Weight of Name_porsche  :   1.0683034691256827
# Weight of Name_renault  :   -0.4040427216445755
# Weight of Name_skoda  :   -0.4047789330920969
# Weight of Name_smart  :   0.0
# Weight of Name_tata  :   -0.5315517662565998
# Weight of Name_toyota  :   -0.07389881343177292
# Weight of Name_volkswagen  :   -0.5334183126588571
# Weight of Name_volvo  :   0.11512835919401358
# Weight of Location_Ahmedabad  :   -0.14367799482711405
# Weight of Location_Bangalore  :   0.3971738841147138
# Weight of Location_Chennai  :   0.17752706181622552
# Weight of Location_Coimbatore  :   0.3296957454929605
# Weight of Location_Delhi  :   -0.26653106012827255
# Weight of Location_Hyderabad  :   0.49034258950050047
# Weight of Location_Jaipur  :   0.0720108891593098
# Weight of Location_Kochi  :   -0.22975606816522126
# Weight of Location_Kolkata  :   -0.4315593552777287
# Weight of Location_Mumbai  :   -0.39860796358517137
# Weight of Location_Pune  :   0.005666173516965081
# Weight of Fuel_Type_Diesel  :   0.4562833109615222
# Weight of Fuel_Type_Electric  :   0.138942092152419
# Weight of Fuel_Type_Petrol  :   -0.4608954963935274
# Weight of Transmission_Automatic  :   0.02283256151957979
# Weight of Transmission_Manual  :   -0.02283256151957979
# Weight of Owner_Type_First  :   0.1676505601674168
# Weight of Owner_Type_Fourth & Above  :   0.06798847417259274
# Weight of Owner_Type_Second  :   -0.14644924173419527
# Weight of Owner_Type_Third  :   -0.09873337501872394
# Weight of Year_1998  :   -0.01675876319243322
# Weight of Year_1999  :   -0.051190138821597723
# Weight of Year_2000  :   -0.08855986667053645
# Weight of Year_2001  :   -0.030051719693728444
# Weight of Year_2002  :   -0.09224259432854857
# Weight of Year_2003  :   -0.27052298950343096
# Weight of Year_2004  :   -0.32323995585520754
# Weight of Year_2005  :   -0.4031562771934165
# Weight of Year_2006  :   -0.5049249718150202
# Weight of Year_2007  :   -0.5564932338400751
# Weight of Year_2008  :   -0.832704397560287
# Weight of Year_2009  :   -0.9400815121598852
# Weight of Year_2010  :   -0.9837410093684671
# Weight of Year_2011  :   -0.9329113483270594
# Weight of Year_2012  :   -0.629026314075186
# Weight of Year_2013  :   -0.3442854674004003
# Weight of Year_2014  :   0.013815082093294104
# Weight of Year_2015  :   0.5419423367932801
# Weight of Year_2016  :   0.8697280461314874
# Weight of Year_2017  :   1.2452343495553164
# Weight of Year_2018  :   1.5090494466839517
# Weight of Year_2019  :   1.014124168154191
# Bias value : 9.606575124804223

# %% [markdown]
# ## Step 4: Work with the generated results.

# %%
predictions, netmse, netrmse, netr2 = get_predictions(X_test, coeffs, affine, y_test) #stores the final predicitons, mean square error, root mse, and r2 score.
print(f"NET REGRESSION STATISTICS:\nFinal Cost Function: {hist[-1]}\nMean Square Error: {netmse}\nRoot Mean Square Error: {netrmse}\nR2 value: {netr2}")
print("*" * 60) #prints the regression statistics
for index, prediction in enumerate(predictions):
  print(f"{test_names[index]}:\nGiven Value:  {y_test[index]}\nPredicted Value: {predictions[index]}\nError:  {(abs(predictions[index]/y_test[index])-1)*100:8.2f}%\n") #prints predictions
#individually prints the actual price, predicted price and error between them for each car in the testing dataset.
# Out:
# NET REGRESSION STATISTICS:
# Final Cost Function: 14.185540332040057
# Mean Square Error: 31.632460646925686
# Root Mean Square Error: 5.6242742329055835
# R2 value: 0.7454560951539715
# ************************************************************
# Maruti Swift Dzire VDI:
# Given Value:  6.95
# Predicted Value: 5.307845084296507
# Error:    -23.63%
#
# Hyundai i10 Sportz AT:
# Given Value:  2.9
# Predicted Value: 0.4579031521981314
# Error:    -84.21%
#
# Hyundai Elite i20 Sportz Plus:
# Given Value:  6.28
# Predicted Value: 6.678340205006006
# Error:      6.34%
#
# Volvo XC60 D5:
# Given Value:  13.8
# Predicted Value: 19.676632552503303
# Error:     42.58%
#
# Hyundai i10 Magna 1.2:
# Given Value:  2.75
# Predicted Value: 0.7657187958433624
# Error:    -72.16%
#
# Audi A6 2.7 TDI:
# Given Value:  11.5
# Predicted Value: 20.384767033293663
# Error:     77.26%
#
# Maruti Swift VXI:
# Given Value:  5.1
# Predicted Value: 5.496480973226633
# Error:      7.77%
#
# Ford Endeavour 3.2 Titanium AT 4X4:
# Given Value:  35.5
# Predicted Value: 26.734118034699137
# Error:    -24.69%
#
# Porsche Panamera Diesel:
# Given Value:  50.5
# Predicted Value: 52.19365139333499
# Error:      3.35%
#
# Hyundai Xcent 1.2 Kappa SX Option:
# Given Value:  4.7
# Predicted Value: 4.148327604090815
# Error:    -11.74%
#
# Ford Figo Diesel ZXI:
# Given Value:  2.6
# Predicted Value: 1.2576244450478011
# Error:    -51.63%
#
# Ford Fiesta 1.4 ZXi TDCi ABS:
# Given Value:  2.75
# Predicted Value: 1.734600569896787
# Error:    -36.92%
#
# Maruti Baleno Zeta Automatic:
# Given Value:  7.22
# Predicted Value: 7.488195956347965
# Error:      3.71%
#
# Mercedes-Benz GL-Class 2007 2012 350 CDI Luxury:
# Given Value:  52.0
# Predicted Value: 31.190221670625412
# Error:    -40.02%
#
# Audi A4 New 2.0 TDI Multitronic:
# Given Value:  13.5
# Predicted Value: 17.35997691380488
# Error:     28.59%
#
# Honda Civic 2010-2013 1.8 S MT:
# Given Value:  2.9
# Predicted Value: 3.531568054880352
# Error:     21.78%
#
# Hyundai Verna CRDi 1.6 SX Option:
# Given Value:  11.5
# Predicted Value: 12.722860066815349
# Error:     10.63%
#
# Maruti Swift Dzire ZXI:
# Given Value:  4.5
# Predicted Value: 3.55890337554282
# Error:    -20.91%
#
# Hyundai i10 Sportz 1.2:
# Given Value:  2.1
# Predicted Value: -2.399005938144242
# Error:     14.24%
#
# Hyundai i20 Sportz 1.4 CRDi:
# Given Value:  7.0
# Predicted Value: 8.653651722678683
# Error:     23.62%
#
# BMW 5 Series 2013-2017 520d Luxury Line:
# Given Value:  30.45
# Predicted Value: 28.203297647047737
# Error:     -7.38%
#
# Toyota Innova 2.5 GX (Diesel) 8 Seater:
# Given Value:  10.9
# Predicted Value: 10.646216962874638
# Error:     -2.33%
#
# Skoda Rapid 1.6 MPI AT Elegance Plus:
# Given Value:  6.11
# Predicted Value: 6.985321081142448
# Error:     14.33%
#
# Audi A4 2.0 TDI 177 Bhp Premium Plus:
# Given Value:  21.43
# Predicted Value: 23.33349459113834
# Error:      8.88%
#
# Mahindra Bolero VLX BS IV:
# Given Value:  4.5
# Predicted Value: 1.6211066162706569
# Error:    -63.98%
#
# Toyota Fortuner 4x2 4 Speed AT:
# Given Value:  19.48
# Predicted Value: 18.713181101502737
# Error:     -3.94%
#
# Skoda Fabia 1.4 MPI Ambiente:
# Given Value:  2.75
# Predicted Value: -0.8361488022927244
# Error:    -69.59%
#
# Mercedes-Benz New C-Class C 220 CDI Elegance AT:
# Given Value:  12.5
# Predicted Value: 24.039015535578244
# Error:     92.31%
#
# Hyundai EON Magna Plus:
# Given Value:  3.5
# Predicted Value: 4.379215351490064
# Error:     25.12%
#
# Chevrolet Enjoy TCDi LTZ 7 Seater:
# Given Value:  4.85
# Predicted Value: 3.294083583966837
# Error:    -32.08%
#
# Ford Ecosport 1.5 Ti VCT MT Titanium:
# Given Value:  5.2
# Predicted Value: 5.553695759837038
# Error:      6.80%
#
# Toyota Camry Hybrid:
# Given Value:  18.75
# Predicted Value: 13.255175220441922
# Error:    -29.31%
#
# Honda Jazz 1.2 SV i VTEC:
# Given Value:  5.6
# Predicted Value: 6.884158054990613
# Error:     22.93%
#
# Honda City i VTEC VX:
# Given Value:  6.9
# Predicted Value: 5.832115390091324
# Error:    -15.48%
#
# Ford EcoSport 1.5 Petrol Titanium:
# Given Value:  9.2
# Predicted Value: 14.395343350040049
# Error:     56.47%
#
# Maruti Vitara Brezza LDi Option:
# Given Value:  7.99
# Predicted Value: 9.933600340141766
# Error:     24.33%
#
# Maruti Swift 1.3 VXi:
# Given Value:  1.6
# Predicted Value: -7.033997392723325
# Error:    339.62%
#
# Toyota Fortuner 4x2 4 Speed AT:
# Given Value:  14.4
# Predicted Value: 14.859365931942802
# Error:      3.19%
#
# Renault Scala Diesel RxL:
# Given Value:  4.75
# Predicted Value: 5.154897922621899
# Error:      8.52%
#
# Mahindra XUV500 W10 AWD:
# Given Value:  16.0
# Predicted Value: 13.796802406898275
# Error:    -13.77%
#
# Toyota Corolla H5:
# Given Value:  1.67
# Predicted Value: 2.831392193600312
# Error:     69.54%
#
# Maruti Zen Estilo LXI BS IV:
# Given Value:  2.6
# Predicted Value: 0.8385714424821842
# Error:    -67.75%
#
# Hyundai Creta 1.6 SX Plus Dual Tone Petrol:
# Given Value:  12.03
# Predicted Value: 13.119551458885748
# Error:      9.06%
#
# Toyota Innova Crysta 2.4 VX MT:
# Given Value:  17.65
# Predicted Value: 17.227572036719252
# Error:     -2.39%
#
# Ford Figo Petrol ZXI:
# Given Value:  2.25
# Predicted Value: 0.904344324040288
# Error:    -59.81%
#
# Honda Amaze S i-Dtech:
# Given Value:  3.25
# Predicted Value: 2.7780369305499644
# Error:    -14.52%
#
# Volkswagen Vento Diesel Highline:
# Given Value:  5.9
# Predicted Value: 6.330832110959582
# Error:      7.30%
#
# Toyota Etios Liva G:
# Given Value:  4.56
# Predicted Value: 6.015541899191276
# Error:     31.92%
#
# Maruti Alto 800 2016-2019 LXI:
# Given Value:  2.65
# Predicted Value: 1.758667934188809
# Error:    -33.64%
#
# Renault KWID 1.0 RXT Optional:
# Given Value:  3.0
# Predicted Value: 3.743682455031186
# Error:     24.79%
#
# Maruti Alto LXi:
# Given Value:  1.5
# Predicted Value: -4.4813618584207
# Error:    198.76%
#
# Honda City 1.5 V AT Exclusive:
# Given Value:  3.71
# Predicted Value: 1.3903256885815818
# Error:    -62.52%
#
# Hyundai EON D Lite Plus:
# Given Value:  3.42
# Predicted Value: 2.703617337886106
# Error:    -20.95%
#
# Ford Endeavour Titanium 4X2:
# Given Value:  27.36
# Predicted Value: 21.1741584032642
# Error:    -22.61%
#
# Mercedes-Benz E-Class 280 CDI:
# Given Value:  10.0
# Predicted Value: 25.40009712831005
# Error:    154.00%
#
# Audi Q5 3.0 TDI Quattro Technology:
# Given Value:  36.83
# Predicted Value: 35.7924397362427
# Error:     -2.82%
#
# Nissan Micra Active XV S:
# Given Value:  3.5
# Predicted Value: 3.0548777999453094
# Error:    -12.72%
#
# Maruti Swift DDiS ZDI Plus:
# Given Value:  8.65
# Predicted Value: 12.535864180746922
# Error:     44.92%
#
# Maruti Alto 800 2016-2019 LXI:
# Given Value:  2.15
# Predicted Value: 1.1222269918191703
# Error:    -47.80%
#
# Chevrolet Beat LT:
# Given Value:  1.6
# Predicted Value: -1.7783812577409766
# Error:     11.15%
#
# Audi Q7 45 TDI Quattro Technology:
# Given Value:  67.0
# Predicted Value: 30.547853713146246
# Error:    -54.41%
#
# Honda City i DTEC VX:
# Given Value:  7.0
# Predicted Value: 6.994488940193177
# Error:     -0.08%
#
# BMW 5 Series 2013-2017 520d Luxury Line:
# Given Value:  23.0
# Predicted Value: 22.957453455577387
# Error:     -0.18%
#
# Toyota Qualis RS E2:
# Given Value:  7.9
# Predicted Value: 9.052810883847025
# Error:     14.59%
#
# Maruti Vitara Brezza VDi Option:
# Given Value:  6.0
# Predicted Value: -1.118276714598366
# Error:    -81.36%
#
# Ford Freestyle Titanium Petrol:
# Given Value:  4.5
# Predicted Value: 5.067306576075674
# Error:     12.61%
#
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV:
# Given Value:  26.52
# Predicted Value: 29.038949991554436
# Error:      9.50%
#
# Jaguar XF 2.2 Litre Luxury:
# Given Value:  1.0
# Predicted Value: -4.839337942391078
# Error:    383.93%
#
# Tata Nano Twist XT:
# Given Value:  4.0
# Predicted Value: 4.421154857583607
# Error:     10.53%
#
# Volkswagen Jetta 2007-2011 1.9 TDI Trendline:
# Given Value:  8.5
# Predicted Value: 8.753043479506662
# Error:      2.98%
#
# Skoda Superb Elegance 2.0 TDI CR AT:
# Given Value:  4.05
# Predicted Value: 5.096348828948913
# Error:     25.84%
#
# Maruti Ritz VXI:
# Given Value:  5.4
# Predicted Value: 9.529377643776845
# Error:     76.47%
#
# Honda Accord 2.4 AT:
# Given Value:  3.25
# Predicted Value: 0.9890595488688305
# Error:    -69.57%
#
# Volkswagen Polo Petrol Highline 1.2L:
# Given Value:  2.9
# Predicted Value: 0.3974575250347474
# Error:    -86.29%
#
# Volkswagen Polo Diesel Trendline 1.2L:
# Given Value:  11.5
# Predicted Value: 9.307956300150707
# Error:    -19.06%
#
# Volkswagen Jetta 2007-2011 1.9 Highline TDI:
# Given Value:  4.6
# Predicted Value: 3.2100659497842505
# Error:    -30.22%
#
# Hyundai i20 1.4 CRDi Asta:
# Given Value:  83.96
# Predicted Value: 49.08633033969194
# Error:    -41.54%
#
# Mercedes-Benz SLC 43 AMG:
# Given Value:  10.15
# Predicted Value: 13.772237135984456
# Error:     35.69%
#
# Maruti Vitara Brezza ZDi Plus:
# Given Value:  4.29
# Predicted Value: 8.909182292810346
# Error:    107.67%
#
# Honda Accord 2.4 MT:
# Given Value:  7.9
# Predicted Value: 13.216118594855335
# Error:     67.29%
#
# Volkswagen Ameo 1.5 TDI Highline:
# Given Value:  2.45
# Predicted Value: 0.5664352184990591
# Error:    -76.88%
#
# Maruti Wagon R VXI BS IV:
# Given Value:  20.25
# Predicted Value: 18.642038801208425
# Error:     -7.94%
#
# Toyota Fortuner 4x2 AT:
# Given Value:  8.45
# Predicted Value: 9.363897522983436
# Error:     10.82%
#
# Maruti Ciaz ZDi Plus SHVS:
# Given Value:  5.65
# Predicted Value: 7.031914341809925
# Error:     24.46%
#
# Maruti Baleno Sigma 1.2:
# Given Value:  37.56
# Predicted Value: 27.412055008263437
# Error:    -27.02%
#
# Audi A6 2011-2015 35 TDI Technology:
# Given Value:  18.98
# Predicted Value: 39.159860221798056
# Error:    106.32%
#
# Land Rover Freelander 2 HSE:
# Given Value:  2.95
# Predicted Value: -3.292340634278503
# Error:     11.60%
#
# Honda City 1.5 GXI:
# Given Value:  6.75
# Predicted Value: 6.537587099714628
# Error:     -3.15%
#
# Mahindra Scorpio VLX 2WD BSIV:
# Given Value:  3.25
# Predicted Value: 12.105733792682294
# Error:    272.48%
#
# Skoda Superb 2.8 V6 AT:
# Given Value:  4.45
# Predicted Value: 5.339387279490934
# Error:     19.99%
#
# Volkswagen Vento 1.6 Highline:
# Given Value:  3.25
# Predicted Value: -0.2232673280862354
# Error:    -93.13%
#
# Hyundai i10 Sportz:
# Given Value:  2.6
# Predicted Value: 1.5854562664612022
# Error:    -39.02%
#
# Hyundai EON D Lite:
# Given Value:  44.0
# Predicted Value: 43.135971151586936
# Error:     -1.96%
#
# Land Rover Range Rover HSE Dynamic:
# Given Value:  5.49
# Predicted Value: 5.761924286184513
# Error:      4.95%
#
# Maruti Baleno Sigma 1.2:
# Given Value:  1.75
# Predicted Value: -2.7410877453385822
# Error:     56.63%
#
# Honda City ZX GXi:
# Given Value:  5.5
# Predicted Value: 7.777132843152037
# Error:     41.40%
#
# Hyundai Grand i10 Asta:
# Given Value:  0.95
# Predicted Value: -7.025920429762483
# Error:    639.57%
#
# Maruti Wagon R VXI BSIII:
# Given Value:  5.95
# Predicted Value: 8.558803332005041
# Error:     43.85%
#
# Maruti Swift VXI BSIV:
# Given Value:  3.6
# Predicted Value: 3.5593836232991087
# Error:     -1.13%
#
# Maruti Wagon R VXI:
# Given Value:  15.95
# Predicted Value: 3.4992749005337798
# Error:    -78.06%
#
# Volkswagen Beetle 2.0:
# Given Value:  7.55
# Predicted Value: 7.8530962409933105
# Error:      4.01%
#
# Maruti Swift ZDi:
# Given Value:  6.63
# Predicted Value: 9.849957886418352
# Error:     48.57%
#
# Volkswagen CrossPolo 1.5 TDI:
# Given Value:  11.25
# Predicted Value: 12.764615882143227
# Error:     13.46%
#
# Honda City i VTEC VX Option:
# Given Value:  17.27
# Predicted Value: 21.116016169260227
# Error:     22.27%
#
# BMW 5 Series 520d Luxury Line:
# Given Value:  29.2
# Predicted Value: 24.13816232586056
# Error:    -17.34%
#
# Ford Endeavour 3.2 Titanium AT 4X4:
# Given Value:  5.2
# Predicted Value: 6.07488424090388
# Error:     16.82%
#
# Volkswagen Vento Diesel Comfortline:
# Given Value:  8.08
# Predicted Value: 9.70588342056816
# Error:     20.12%
#
# Maruti Swift Dzire AMT ZDI:
# Given Value:  4.7
# Predicted Value: 7.201645438099409
# Error:     53.23%
#
# Toyota Etios G SP:
# Given Value:  8.75
# Predicted Value: 8.132937600221528
# Error:     -7.05%
#
# Mitsubishi Pajero 2.8 SFX:
# Given Value:  2.21
# Predicted Value: 0.46486901718706974
# Error:    -78.97%
#
# Chevrolet Beat LS:
# Given Value:  5.27
# Predicted Value: 5.133157399328897
# Error:     -2.60%
#
# Ford Ecosport 1.5 DV5 MT Ambiente:
# Given Value:  2.62
# Predicted Value: -1.2090299064858279
# Error:    -53.85%
#
# Maruti Zen Estilo 1.1 LX BSIII:
# Given Value:  2.3
# Predicted Value: -0.5487126113149507
# Error:    -76.14%
#
# Mahindra Renault Logan 1.5 DLE Diesel:
# Given Value:  3.5
# Predicted Value: 8.46658836742271
# Error:    141.90%
#
# Honda Accord 2.4 Inspire M/T:
# Given Value:  3.25
# Predicted Value: 2.760218624487396
# Error:    -15.07%
#
# Ford Figo Diesel Titanium:
# Given Value:  4.0
# Predicted Value: 6.285775319372338
# Error:     57.14%
#
# Mahindra Scorpio 2.6 CRDe:
# Given Value:  5.7
# Predicted Value: 5.22647249640433
# Error:     -8.31%
#
# Volkswagen Polo Diesel Highline 1.2L:
# Given Value:  2.8
# Predicted Value: 5.045094815631501
# Error:     80.18%
#
# Tata Indigo CS eVX:
# Given Value:  3.0
# Predicted Value: 1.6454948315034583
# Error:    -45.15%
#
# Nissan Sunny 2011-2014 XL:
# Given Value:  6.7
# Predicted Value: 10.4234419598911
# Error:     55.57%
#
# Honda Amaze V Petrol:
# Given Value:  31.0
# Predicted Value: 21.599991122599786
# Error:    -30.32%
#
# Toyota Fortuner 2.8 2WD AT:
# Given Value:  11.5
# Predicted Value: 10.915413417696984
# Error:     -5.08%
#
# Honda City i VTEC CVT VX:
# Given Value:  6.25
# Predicted Value: 5.531486846269992
# Error:    -11.50%
#
# Mahindra XUV500 W8 2WD:
# Given Value:  4.25
# Predicted Value: 5.524808083497539
# Error:     30.00%
#
# Volkswagen Vento Diesel Comfortline:
# Given Value:  4.0
# Predicted Value: 3.6509130953292903
# Error:     -8.73%
#
# Hyundai Grand i10 Magna:
# Given Value:  3.0
# Predicted Value: 1.6820954670838946
# Error:    -43.93%
#
# Skoda Fabia 1.2L Diesel Classic:
# Given Value:  2.99
# Predicted Value: 3.013010630329333
# Error:      0.77%
#
# Toyota Etios VX:
# Given Value:  6.25
# Predicted Value: 8.359427359933187
# Error:     33.75%
#
# Mahindra KUV 100 G80 K8:
# Given Value:  3.15
# Predicted Value: 3.5439380349226486
# Error:     12.51%
#
# Chevrolet Beat Diesel LS:
# Given Value:  7.25
# Predicted Value: 8.567303362347106
# Error:     18.17%
#
# Skoda Superb Elegance 1.8 TSI AT:
# Given Value:  1.7
# Predicted Value: -4.153166236030309
# Error:    144.30%
#
# Hyundai i10 Sportz 1.2:
# Given Value:  3.5
# Predicted Value: 0.6078940541147357
# Error:    -82.63%
#
# Hyundai i10 Sportz AT:
# Given Value:  16.5
# Predicted Value: 15.527178808637032
# Error:     -5.90%
#
# Toyota Fortuner 4x2 AT:
# Given Value:  2.85
# Predicted Value: 1.4034477836061345
# Error:    -50.76%
#
# Maruti Ritz VDi:
# Given Value:  5.4
# Predicted Value: 4.269229565036144
# Error:    -20.94%
#
# Honda Brio VX AT:
# Given Value:  17.0
# Predicted Value: 26.46157366235192
# Error:     55.66%
#
# Mini Cooper S:
# Given Value:  3.7
# Predicted Value: 2.044014146577224
# Error:    -44.76%
#
# Chevrolet Beat Diesel LS:
# Given Value:  7.85
# Predicted Value: 8.589683632701664
# Error:      9.42%
#
# Mahindra XUV500 W8 2WD:
# Given Value:  48.0
# Predicted Value: 32.64189202142934
# Error:    -32.00%
#
# Audi Q7 35 TDI Quattro Technology:
# Given Value:  21.5
# Predicted Value: 20.88226184564327
# Error:     -2.87%
#
# Audi Q5 2.0 TDI:
# Given Value:  6.2
# Predicted Value: 8.958550803023485
# Error:     44.49%
#
# Nissan Sunny XL:
# Given Value:  8.25
# Predicted Value: 10.479904933020066
# Error:     27.03%
#
# Maruti Ertiga Paseo VXI:
# Given Value:  6.56
# Predicted Value: 3.0489484259633546
# Error:    -53.52%
#
# Maruti Ertiga ZDI:
# Given Value:  29.5
# Predicted Value: 21.287533961842193
# Error:    -27.84%
#
# Audi A6 2.0 TDI Design Edition:
# Given Value:  13.5
# Predicted Value: 15.570543184428875
# Error:     15.34%
#
# Toyota Camry 2.5 G:
# Given Value:  3.3
# Predicted Value: 2.105432338872606
# Error:    -36.20%
#
# Tata Indica Vista TDI LS:
# Given Value:  2.11
# Predicted Value: -1.5719926081903282
# Error:    -25.50%
#
# Honda City ZX VTEC:
# Given Value:  6.0
# Predicted Value: 8.81003732613193
# Error:     46.83%
#
# Ford EcoSport 1.5 Petrol Trend:
# Given Value:  9.5
# Predicted Value: 18.920668301933343
# Error:     99.16%
#
# BMW X1 sDrive 18i:
# Given Value:  13.5
# Predicted Value: 18.105906556068113
# Error:     34.12%
#
# Audi A4 2.0 TDI Multitronic:
# Given Value:  1.02
# Predicted Value: -6.321016048267683
# Error:    519.71%
#
# Maruti Alto LX:
# Given Value:  3.3
# Predicted Value: 3.856663220922968
# Error:     16.87%
#
# Toyota Etios GD:
# Given Value:  3.6
# Predicted Value: 4.498718177664206
# Error:     24.96%
#
# Mahindra Quanto C2:
# Given Value:  51.0
# Predicted Value: 40.90479875221233
# Error:    -19.79%
#
# Maruti Ritz AT:
# Given Value:  50.22
# Predicted Value: 33.05662074894328
# Error:    -34.18%
#
# Audi Q7 4.2 TDI Quattro Technology:
# Given Value:  2.7
# Predicted Value: -2.849796215522801
# Error:      5.55%
#
# Audi Q7 35 TDI Quattro Technology:
# Given Value:  23.68
# Predicted Value: 22.632338191758045
# Error:     -4.42%
#
# Hyundai i20 2015-2017 Asta:
# Given Value:  93.0
# Predicted Value: 41.50213040327425
# Error:    -55.37%
#
# Audi Q5 2008-2012 2.0 TDI:
# Given Value:  2.05
# Predicted Value: 1.057818755233301
# Error:    -48.40%
#
# BMW 7 Series 740Li:
# Given Value:  14.4
# Predicted Value: 15.857032697426483
# Error:     10.12%
#
# Hyundai Accent GLE:
# Given Value:  6.5
# Predicted Value: 9.597782518304873
# Error:     47.66%
#
# Maruti Swift VDI BSIV W ABS:
# Given Value:  3.9
# Predicted Value: 22.740982771820462
# Error:    483.10%
#
# Hyundai Santa Fe 4WD AT:
# Given Value:  35.0
# Predicted Value: 38.96581440066291
# Error:     11.33%
#
# Nissan Terrano XV 110 PS Limited Edition:
# Given Value:  3.85
# Predicted Value: 3.364312202742288
# Error:    -12.62%
#
# Mercedes-Benz E-Class 250 D W 210:
# Given Value:  4.0
# Predicted Value: 3.1363526006915388
# Error:    -21.59%
#
# Land Rover Discovery Sport TD4 HSE:
# Given Value:  3.5
# Predicted Value: 5.808191324155823
# Error:     65.95%
#
# Maruti Estilo LXI:
# Given Value:  55.76
# Predicted Value: 47.927437671769674
# Error:    -14.05%
#
# Toyota Etios Liva 1.4 GD:
# Given Value:  9.0
# Predicted Value: 9.481125206110898
# Error:      5.35%
#
# Hyundai i20 1.4 Asta CRDi with AVN:
# Given Value:  3.65
# Predicted Value: 9.288189867109208
# Error:    154.47%
#
# Maruti Wagon R VXI 1.2:
# Given Value:  2.9
# Predicted Value: 1.7366481523830322
# Error:    -40.12%
#
# Land Rover Range Rover 2.2L Dynamic:
# Given Value:  2.3
# Predicted Value: -1.8493860200434753
# Error:    -19.59%
#
# Mahindra XUV500 W8 4WD:
# Given Value:  17.5
# Predicted Value: 18.814503418627677
# Error:      7.51%
#
# Maruti Ritz LDi:
# Given Value:  13.5
# Predicted Value: 12.903589176291904
# Error:     -4.42%
#
# Ford Figo Diesel ZXI:
# Given Value:  17.63
# Predicted Value: 19.034037940718317
# Error:      7.96%
#
# Nissan Micra XE:
# Given Value:  6.25
# Predicted Value: 6.625438829409062
# Error:      6.01%
#
# Audi A6 2011-2015 2.0 TDI Premium Plus:
# Given Value:  3.8
# Predicted Value: 2.3601686929198893
# Error:    -37.89%
#
# Toyota Innova 2.5 V Diesel 8-seater:
# Given Value:  8.5
# Predicted Value: 18.72303732820064
# Error:    120.27%
#
# Mahindra XUV500 W9 AT:
# Given Value:  9.5
# Predicted Value: 20.295090156800143
# Error:    113.63%
#
# Honda Jazz 1.5 SV i DTEC:
# Given Value:  3.0
# Predicted Value: 1.5116905653151154
# Error:    -49.61%
#
# Volkswagen Polo Diesel Highline 1.2L:
# Given Value:  3.15
# Predicted Value: 2.187470098464713
# Error:    -30.56%
#
# Mercedes-Benz New C-Class C 200 CGI Avantgarde:
# Given Value:  19.5
# Predicted Value: 21.01509095556792
# Error:      7.77%
#
# Mercedes-Benz New C-Class C 220 CDI Elegance AT:
# Given Value:  6.0
# Predicted Value: 4.547665224795956
# Error:    -24.21%
#
# Maruti Wagon R LXI BS IV:
# Given Value:  2.1
# Predicted Value: 0.1386032868722591
# Error:    -93.40%
#
# Maruti Swift LXI:
# Given Value:  12.0
# Predicted Value: 9.473885328553736
# Error:    -21.05%
#
# Audi A4 2.0 TDI:
# Given Value:  2.75
# Predicted Value: 3.1401405807844567
# Error:     14.19%
#
# Honda City i DTEC SV:
# Given Value:  3.0
# Predicted Value: 4.331985974909635
# Error:     44.40%
#
# Ford Figo Diesel Titanium:
# Given Value:  5.17
# Predicted Value: 6.093685688493642
# Error:     17.87%
#
# Toyota Innova 2.5 V Diesel 8-seater:
# Given Value:  15.5
# Predicted Value: 14.1170754503208
# Error:     -8.92%
#
# Honda Civic 2006-2010 1.8 S MT:
# Given Value:  4.94
# Predicted Value: 4.288942407866453
# Error:    -13.18%
#
# Nissan Micra XL:
# Given Value:  18.0
# Predicted Value: 19.625666422162446
# Error:      9.03%
#
# Maruti Swift Dzire VDI:
# Given Value:  4.8
# Predicted Value: 5.176774853700118
# Error:      7.85%
#
# Skoda Superb Style 2.0 TDI AT:
# Given Value:  4.65
# Predicted Value: 2.851482248891358
# Error:    -38.68%
#
# Honda Amaze E i-Vtech:
# Given Value:  5.5
# Predicted Value: 12.005638071089642
# Error:    118.28%
#
# Toyota Innova Crysta 2.8 ZX AT:
# Given Value:  5.75
# Predicted Value: 6.8575940571806235
# Error:     19.26%
#
# Maruti Swift Dzire Tour LDI:
# Given Value:  2.1
# Predicted Value: -2.2539075063505543
# Error:      7.33%
#
# Maruti Swift VDI:
# Given Value:  20.5
# Predicted Value: 21.65340255648502
# Error:      5.63%
#
# Maruti Swift Dzire Tour LDI:
# Given Value:  0.8
# Predicted Value: 1.0842157568122683
# Error:     35.53%
#
# Maruti Swift Dzire VDI:
# Given Value:  5.18
# Predicted Value: 8.81772428204661
# Error:     70.23%
#
# Maruti Alto LXi:
# Given Value:  4.5
# Predicted Value: 6.113767747102387
# Error:     35.86%
#
# Audi A4 2.0 TDI Multitronic:
# Given Value:  52.0
# Predicted Value: 31.927241448140208
# Error:    -38.60%
#
# Ford Ikon 1.3 Flair:
# Given Value:  3.89
# Predicted Value: 1.1907147604370554
# Error:    -69.39%
#
# Maruti Wagon R AMT VXI:
# Given Value:  11.9
# Predicted Value: 11.445155235391766
# Error:     -3.82%
#
# Hyundai Grand i10 CRDi Sportz:
# Given Value:  4.5
# Predicted Value: 6.278518637714843
# Error:     39.52%
#
# Jaguar XF 2.0 Diesel Portfolio:
# Given Value:  4.89
# Predicted Value: -0.22481496211799268
# Error:    -95.40%
#
# Honda Amaze S i-VTEC:
# Given Value:  18.75
# Predicted Value: 20.059411971954944
# Error:      6.98%
#
# Hyundai Creta 1.6 CRDi SX Option:
# Given Value:  4.8
# Predicted Value: 8.326054025593722
# Error:     73.46%
#
# Maruti Swift LDI Optional:
# Given Value:  5.53
# Predicted Value: 8.96880283807832
# Error:     62.18%
#
# Volkswagen Polo Petrol Highline 1.2L:
# Given Value:  1.75
# Predicted Value: -3.78873985944667
# Error:    116.50%
#
# Toyota Innova Crysta 2.4 ZX MT:
# Given Value:  3.6
# Predicted Value: 4.226113822533424
# Error:     17.39%
#
# Volkswagen Polo GT TDI:
# Given Value:  4.0
# Predicted Value: 6.227498499940384
# Error:     55.69%
#
# Mitsubishi Outlander 2.4:
# Given Value:  9.0
# Predicted Value: 18.20447742349063
# Error:    102.27%
#
# Maruti Wagon R VXI:
# Given Value:  2.95
# Predicted Value: 1.7214891262711634
# Error:    -41.64%
#
# Hyundai i10 Sportz:
# Given Value:  26.11
# Predicted Value: 20.574568961437123
# Error:    -21.20%
#
# Toyota Innova 2.5 V Diesel 7-seater:
# Given Value:  4.21
# Predicted Value: 1.8939537091973069
# Error:    -55.01%
#
# Maruti Grand Vitara 2.4 MT:
# Given Value:  7.4
# Predicted Value: 10.423015238051242
# Error:     40.85%
#
# Tata Manza Aura Quadrajet BS IV:
# Given Value:  6.0
# Predicted Value: 5.507386884790935
# Error:     -8.21%
#
# Toyota Camry Hybrid 2.5:
# Given Value:  2.4
# Predicted Value: -1.1433435692824325
# Error:    -52.36%
#
# Honda City 1.5 S MT:
# Given Value:  22.2
# Predicted Value: 22.415040595011195
# Error:      0.97%
#
# Mahindra Scorpio 2009-2014 SLE 7S BSIV:
# Given Value:  3.25
# Predicted Value: 2.3779222214440425
# Error:    -26.83%
#
# Hyundai i20 1.2 Sportz:
# Given Value:  10.65
# Predicted Value: 9.964306192736359
# Error:     -6.44%
#
# Ford Figo Petrol Titanium:
# Given Value:  38.99
# Predicted Value: 33.10007007188359
# Error:    -15.11%
#
# Toyota Innova Crysta 2.4 VX MT:
# Given Value:  3.45
# Predicted Value: -1.2002837718732167
# Error:    -65.21%
#
# Volkswagen Polo Diesel Comfortline 1.2L:
# Given Value:  10.36
# Predicted Value: 21.278407763873876
# Error:    105.39%
#
# Honda City i-VTEC CVT VX:
# Given Value:  3.39
# Predicted Value: 2.9636814276370025
# Error:    -12.58%
#
# Mercedes-Benz New C-Class Progressive C 200:
# Given Value:  6.7
# Predicted Value: 7.593695351124545
# Error:     13.34%
#
# Hyundai i10 Asta AT:
# Given Value:  14.82
# Predicted Value: 14.28301561836907
# Error:     -3.62%
#
# Mercedes-Benz New C-Class 220 CDI MT:
# Given Value:  3.91
# Predicted Value: 1.8728294292555105
# Error:    -52.10%
#
# Volkswagen Vento Petrol Highline:
# Given Value:  36.0
# Predicted Value: 30.06028776725237
# Error:    -16.50%
#
# Maruti Ciaz ZXi Plus:
# Given Value:  7.0
# Predicted Value: 7.880007110787412
# Error:     12.57%
#
# Hyundai Creta 1.6 SX Plus Diesel:
# Given Value:  3.55
# Predicted Value: 4.82439409582008
# Error:     35.90%
#
# Maruti Swift VXI:
# Given Value:  2.5
# Predicted Value: -0.5214562392901456
# Error:    -79.14%
#
# Mercedes-Benz New C-Class C 220 CDI Style:
# Given Value:  17.5
# Predicted Value: 20.948049371780932
# Error:     19.70%
#
# Skoda Rapid 1.6 MPI Elegance:
# Given Value:  23.41
# Predicted Value: 28.746351203343963
# Error:     22.80%
#
# Maruti Swift VDI BSIV:
# Given Value:  4.35
# Predicted Value: 3.5476787097044085
# Error:    -18.44%
#
# Maruti Ritz VXi:
# Given Value:  17.11
# Predicted Value: 18.225269003487092
# Error:      6.52%
#
# Audi A4 2.0 TDI 177 Bhp Premium Plus:
# Given Value:  2.79
# Predicted Value: 2.337278404619524
# Error:    -16.23%
#
# Mercedes-Benz E-Class E250 CDI Avantgrade:
# Given Value:  30.0
# Predicted Value: 25.969201058799776
# Error:    -13.44%
#
# Volkswagen Polo 1.2 MPI Highline:
# Given Value:  21.37
# Predicted Value: 19.317819221143772
# Error:     -9.60%
#
# Toyota Fortuner 4x2 AT:
# Given Value:  3.5
# Predicted Value: 4.971521233703989
# Error:     42.04%
#
# Maruti Celerio VXI:
# Given Value:  4.9
# Predicted Value: 6.288555505124155
# Error:     28.34%
#
# Mercedes-Benz New C-Class C 220d Avantgarde Edition C:
# Given Value:  8.9
# Predicted Value: 6.987814057791565
# Error:    -21.49%
#
# Hyundai Santa Fe 4WD AT:
# Given Value:  3.65
# Predicted Value: 3.1934845571740444
# Error:    -12.51%
#
# Hyundai Verna Transform CRDi VGT SX ABS:
# Given Value:  3.49
# Predicted Value: 2.6492722418713655
# Error:    -24.09%
#
# Skoda Superb Elegance 1.8 TSI AT:
# Given Value:  8.65
# Predicted Value: 6.9980969015127545
# Error:    -19.10%
#
# Honda City i VTEC CVT VX:
# Given Value:  4.0
# Predicted Value: 6.438120587486406
# Error:     60.95%
#
# Skoda Laura Ambiente 2.0 TDI CR MT:
# Given Value:  6.0
# Predicted Value: 6.6496160359425245
# Error:     10.83%
#
# Honda Brio S MT:
# Given Value:  9.4
# Predicted Value: 14.352094024786792
# Error:     52.68%
#
# Honda City i-VTEC CVT VX:
# Given Value:  5.25
# Predicted Value: 5.807649129310238
# Error:     10.62%
#
# Chevrolet Captiva LTZ VCDi:
# Given Value:  39.51
# Predicted Value: 32.42097985389073
# Error:    -17.94%
#
# Hyundai i20 1.2 Magna Executive:
# Given Value:  4.85
# Predicted Value: 5.170966429798906
# Error:      6.62%
#
# Maruti Vitara Brezza VDi Option:
# Given Value:  6.75
# Predicted Value: 7.871647913358976
# Error:     16.62%
#
# Hyundai Xcent 1.1 CRDi S Celebration Edition:
# Given Value:  2.9
# Predicted Value: 5.230427583060643
# Error:     80.36%
#
# Mercedes-Benz New C-Class C 220d Avantgarde Edition C:
# Given Value:  5.25
# Predicted Value: 3.735481198839663
# Error:    -28.85%
#
# Maruti Swift Dzire LDI:
# Given Value:  9.25
# Predicted Value: 9.21245260386936
# Error:     -0.41%
#
# Renault Duster 110PS Diesel RxZ:
# Given Value:  6.25
# Predicted Value: 9.134300999866024
# Error:     46.15%
#
# Maruti Alto 800 2016-2019 LXI:
# Given Value:  20.25
# Predicted Value: 17.741363451826047
# Error:    -12.39%
#
# Honda Mobilio S i VTEC:
# Given Value:  4.75
# Predicted Value: 6.646515240544611
# Error:     39.93%
#
# Maruti Vitara Brezza ZDi Plus Dual Tone:
# Given Value:  4.94
# Predicted Value: 3.848200236338635
# Error:    -22.10%
#
# Volkswagen Polo 1.5 TDI Highline:
# Given Value:  5.04
# Predicted Value: 5.394008404864038
# Error:      7.02%
#
# Toyota Innova Crysta 2.4 ZX MT:
# Given Value:  1.96
# Predicted Value: -0.2786252873819812
# Error:    -85.78%
#
# Hyundai Grand i10 SportZ Edition:
# Given Value:  4.0
# Predicted Value: 5.764056446393793
# Error:     44.10%
#
# Honda Amaze SX i-VTEC:
# Given Value:  5.65
# Predicted Value: 11.98305399282961
# Error:    112.09%
#
# Hyundai Grand i10 Sportz:
# Given Value:  7.5
# Predicted Value: 14.949074057874686
# Error:     99.32%
#
# Honda City ZX CVT:
# Given Value:  8.65
# Predicted Value: 9.312574382380273
# Error:      7.66%
#
# Toyota Corolla Altis VL:
# Given Value:  3.95
# Predicted Value: 4.950392380908248
# Error:     25.33%
#
# Maruti Swift VXI BSIII W/ ABS:
# Given Value:  3.88
# Predicted Value: 3.7995154481237856
# Error:     -2.07%
#
# Mitsubishi Montero 3.2 GLS:
# Given Value:  4.45
# Predicted Value: 6.945265313908899
# Error:     56.07%
#
# Ford EcoSport 1.5 Ti VCT MT Titanium BE:
# Given Value:  3.5
# Predicted Value: 2.119005666432815
# Error:    -39.46%
#
# Maruti Wagon R VXI AMT:
# Given Value:  3.6
# Predicted Value: 4.634002478561238
# Error:     28.72%
#
# Chevrolet Enjoy TCDi LS 8 Seater:
# Given Value:  4.8
# Predicted Value: 6.807719136097181
# Error:     41.83%
#
# Renault KWID RXT Optional:
# Given Value:  4.5
# Predicted Value: 6.4891477512917595
# Error:     44.20%
#
# Toyota Qualis FS B2:
# Given Value:  2.6
# Predicted Value: -1.7754444638807243
# Error:    -31.71%
#
# Maruti Ritz VDi:
# Given Value:  1.95
# Predicted Value: -1.6284417786716219
# Error:    -16.49%
#
# Maruti Ertiga VDI Limited Edition:
# Given Value:  4.72
# Predicted Value: 2.3267858114435205
# Error:    -50.70%
#
# Tata Zest Revotron 1.2T XE:
# Given Value:  2.2
# Predicted Value: 0.6161657534897653
# Error:    -71.99%
#
# Hyundai i10 Magna:
# Given Value:  5.1
# Predicted Value: 4.309849866951446
# Error:    -15.49%
#
# Maruti A-Star Vxi:
# Given Value:  7.75
# Predicted Value: 5.842481760112494
# Error:    -24.61%
#
# Hyundai Grand i10 CRDi Sportz:
# Given Value:  12.75
# Predicted Value: 11.280083697530339
# Error:    -11.53%
#
# Skoda Octavia 1.9 TDI:
# Given Value:  3.9
# Predicted Value: 3.5574318495783457
# Error:     -8.78%
#
# Hyundai Grand i10 AT Asta:
# Given Value:  2.4
# Predicted Value: 0.507588386704219
# Error:    -78.85%
#
# Volkswagen Vento TSI:
# Given Value:  4.25
# Predicted Value: 2.7467869915537655
# Error:    -35.37%
#
# Toyota Prius 2009-2016 Z4:
# Given Value:  11.77
# Predicted Value: 17.052021585102047
# Error:     44.88%
#
# Maruti Ritz VXI:
# Given Value:  6.02
# Predicted Value: 13.03791588271922
# Error:    116.58%
#
# Maruti Swift VXI BSIII:
# Given Value:  25.75
# Predicted Value: 28.65809446121035
# Error:     11.29%
#
# Honda Civic 2006-2010 1.8 S MT:
# Given Value:  27.0
# Predicted Value: 25.577817743044058
# Error:     -5.27%
#
# Mercedes-Benz B Class B180:
# Given Value:  12.75
# Predicted Value: 12.712818949612426
# Error:     -0.29%
#
# Chevrolet Cruze LTZ:
# Given Value:  2.25
# Predicted Value: 0.6640214178566382
# Error:    -70.49%
#
# Mercedes-Benz CLA 200 CDI Sport:
# Given Value:  5.85
# Predicted Value: 9.105665676714539
# Error:     55.65%
#
# Audi A4 35 TDI Technology Edition:
# Given Value:  2.6
# Predicted Value: 6.797440500302257
# Error:    161.44%
#
# Mitsubishi Pajero Sport 4X4:
# Given Value:  6.89
# Predicted Value: 8.008159160144261
# Error:     16.23%
#
# Maruti Zen Estilo VXI BSIII:
# Given Value:  3.25
# Predicted Value: 2.0120474823097743
# Error:    -38.09%
#
# Hyundai i20 Magna 1.2:
# Given Value:  49.0
# Predicted Value: 32.20562561983894
# Error:    -34.27%
#
# Honda Accord 2.4 AT:
# Given Value:  8.4
# Predicted Value: 11.017480089216308
# Error:     31.16%
#
# Skoda Superb Elegance 1.8 TSI AT:
# Given Value:  12.5
# Predicted Value: 13.360513662932128
# Error:      6.88%
#
# Maruti Wagon R LXI BS IV:
# Given Value:  19.0
# Predicted Value: 24.048668661159354
# Error:     26.57%
#
# Mercedes-Benz GL-Class 2007 2012 350 CDI Luxury:
# Given Value:  5.84
# Predicted Value: 8.511109474343618
# Error:     45.74%
#
# Honda City 1.5 V MT:
# Given Value:  19.5
# Predicted Value: 26.73002143868314
# Error:     37.08%
#
# Toyota Corolla Altis 2008-2013 1.8 VL AT:
# Given Value:  6.25
# Predicted Value: 6.665955255728711
# Error:      6.66%
#
# Audi Q3 35 TDI Quattro Premium:
# Given Value:  28.0
# Predicted Value: 26.9023275620178
# Error:     -3.92%
#
# Hyundai Grand i10 Sportz:
# Given Value:  4.4
# Predicted Value: 6.7748607853801195
# Error:     53.97%
#
# BMW 7 Series 730Ld:
# Given Value:  5.0
# Predicted Value: 9.959350043884578
# Error:     99.19%
#
# Volkswagen Vento 1.5 Highline Plus AT 16 Alloy:
# Given Value:  4.5
# Predicted Value: 6.139006621453508
# Error:     36.42%
#
# Mercedes-Benz New C-Class C 220 CDI BE Avantgare:
# Given Value:  6.0
# Predicted Value: 9.1789348902685
# Error:     52.98%
#
# Honda Amaze VX i-DTEC:
# Given Value:  13.0
# Predicted Value: 10.63224407092808
# Error:    -18.21%
#
# Hyundai Xcent 1.2 VTVT E Plus:
# Given Value:  12.25
# Predicted Value: 12.944418990529824
# Error:      5.67%
#
# Honda Amaze S i-Dtech:
# Given Value:  5.15
# Predicted Value: 6.283144050972477
# Error:     22.00%
#
# Ford EcoSport 1.5 TDCi Ambiente:
# Given Value:  3.5
# Predicted Value: 0.5210064589330159
# Error:    -85.11%
#
# Mahindra XUV500 W10 2WD:
# Given Value:  2.65
# Predicted Value: -1.9093301136945193
# Error:    -27.95%
#
# Volkswagen Vento 1.5 Highline Plus AT 16 Alloy:
# Given Value:  6.8
# Predicted Value: 9.304206995606773
# Error:     36.83%
#
# Hyundai Grand i10 Asta Option:
# Given Value:  3.19
# Predicted Value: 1.3402757608933484
# Error:    -57.99%
#
# Honda City 1.3 EXI S:
# Given Value:  11.99
# Predicted Value: -3.388921463372604
# Error:    -71.74%
#
# Hyundai i10 Magna:
# Given Value:  44.0
# Predicted Value: 31.229150907126854
# Error:    -29.02%
#
# Mahindra Xylo D4 BS III:
# Given Value:  2.15
# Predicted Value: -2.1705497993399057
# Error:      0.96%
#
# Tata Nano XTA:
# Given Value:  16.5
# Predicted Value: 16.553078486209337
# Error:      0.32%
#
# Honda CR-V AT With Sun Roof:
# Given Value:  8.5
# Predicted Value: 16.648106905008916
# Error:     95.86%
#
# Audi Q5 2008-2012 3.0 TDI:
# Given Value:  5.32
# Predicted Value: 2.5033035540224624
# Error:    -52.95%
#
# Hyundai i10 Magna 1.2:
# Given Value:  4.25
# Predicted Value: 4.913984564036081
# Error:     15.62%
#
# Toyota Fortuner 4x2 Manual:
# Given Value:  9.4
# Predicted Value: 10.122527639323255
# Error:      7.69%
#
# BMW 3 Series 320d Highline:
# Given Value:  11.11
# Predicted Value: 10.797098422559605
# Error:     -2.82%
#
# Hyundai i20 Sportz Option:
# Given Value:  19.4
# Predicted Value: 23.85603126915121
# Error:     22.97%
#
# Skoda Laura Elegance MT:
# Given Value:  3.5
# Predicted Value: 5.407789472857373
# Error:     54.51%
#
# Mahindra XUV500 W6 2WD:
# Given Value:  5.1
# Predicted Value: 3.683023591047128
# Error:    -27.78%
#
# Toyota Innova 2.5 VX (Diesel) 7 Seater:
# Given Value:  2.5
# Predicted Value: 1.6761197739156302
# Error:    -32.96%
#
# Toyota Innova Crysta 2.8 GX AT:
# Given Value:  6.25
# Predicted Value: 5.6786625501125085
# Error:     -9.14%
#
# Renault KWID RXT Optional:
# Given Value:  5.95
# Predicted Value: 5.649376329459065
# Error:     -5.05%
#
# Volkswagen Polo Petrol Highline 1.2L:
# Given Value:  2.2
# Predicted Value: 0.870982038143719
# Error:    -60.41%
#
# Hyundai EON Era Plus:
# Given Value:  4.6
# Predicted Value: 5.34107334383174
# Error:     16.11%
#
# Honda City i VTEC SV:
# Given Value:  4.95
# Predicted Value: 4.216747673150197
# Error:    -14.81%
#
# Honda City i VTEC V:
# Given Value:  9.75
# Predicted Value: 8.902293024381336
# Error:     -8.69%
#
# Maruti Wagon R LXI BSIII:
# Given Value:  5.1
# Predicted Value: 7.281529987856064
# Error:     42.78%
#
# Hyundai Grand i10 Sportz:
# Given Value:  18.25
# Predicted Value: 16.732885030363242
# Error:     -8.31%
#
# Honda City 1.5 V MT Sunroof:
# Given Value:  25.0
# Predicted Value: 25.506803628947438
# Error:      2.03%
#
# Maruti SX4 S Cross DDiS 200 Zeta:
# Given Value:  4.25
# Predicted Value: 4.361413889298115
# Error:      2.62%
#
# Hyundai Verna 1.6 SX CRDI (O) AT:
# Given Value:  5.75
# Predicted Value: 4.7139573829003725
# Error:    -18.02%
#
# Volvo XC60 D4 Summum:
# Given Value:  6.5
# Predicted Value: 6.028996157017882
# Error:     -7.25%
#
# Audi A4 35 TDI Premium:
# Given Value:  1.95
# Predicted Value: -0.9371320219002133
# Error:    -51.94%
#
# Maruti Wagon R AMT VXI:
# Given Value:  4.96
# Predicted Value: 3.8622844208549534
# Error:    -22.13%
#
# Maruti Ciaz ZDi Plus:
# Given Value:  9.2
# Predicted Value: 8.924838251398043
# Error:     -2.99%
#
# Maruti Baleno Alpha 1.2:
# Given Value:  3.15
# Predicted Value: 1.78536655321681
# Error:    -43.32%
#
# Maruti Swift Lxi BSIII:
# Given Value:  10.95
# Predicted Value: 14.181843923224129
# Error:     29.51%
#
# Hyundai Grand i10 CRDi SportZ Edition:
# Given Value:  4.25
# Predicted Value: 2.0253527816293273
# Error:    -52.34%
#
# Maruti Ciaz 1.4 AT Alpha:
# Given Value:  2.75
# Predicted Value: 0.2251152129296532
# Error:    -91.81%
#
# Honda City 1.5 V MT:
# Given Value:  4.0
# Predicted Value: 7.3742815624351685
# Error:     84.36%
#
# Hyundai Verna CRDi 1.6 SX Option:
# Given Value:  29.8
# Predicted Value: 20.651952581335586
# Error:    -30.70%
#
# Volkswagen Polo Diesel Comfortline 1.2L:
# Given Value:  4.65
# Predicted Value: 4.487118676947778
# Error:     -3.50%
#
# Honda City 1.5 S MT:
# Given Value:  4.7
# Predicted Value: 5.190843326049101
# Error:     10.44%
#
# Volkswagen Polo 1.5 TDI Comfortline:
# Given Value:  8.1
# Predicted Value: 6.384112630798652
# Error:    -21.18%
#
# Ford Endeavour 3.2 Titanium AT 4X4:
# Given Value:  1.3
# Predicted Value: 0.15290718137803871
# Error:    -88.24%
#
# Volkswagen Vento IPL II Petrol Highline AT:
# Given Value:  5.75
# Predicted Value: 5.81487639733983
# Error:      1.13%
#
# Honda Amaze EX i-Dtech:
# Given Value:  5.5
# Predicted Value: 3.1079469550528938
# Error:    -43.49%
#
# Mahindra XUV500 W8 2WD:
# Given Value:  2.5
# Predicted Value: 1.2173106435496521
# Error:    -51.31%
#
# Honda City 1.3 EXI:
# Given Value:  3.25
# Predicted Value: 3.529225289667293
# Error:      8.59%
#
# Ford EcoSport 1.5 Ti VCT MT Titanium:
# Given Value:  5.5
# Predicted Value: 6.398170165377501
# Error:     16.33%
#
# Hyundai i20 1.4 CRDi Asta:
# Given Value:  13.25
# Predicted Value: 14.292294010596208
# Error:      7.87%
#
# Honda City 1.5 E MT:
# Given Value:  2.6
# Predicted Value: 3.6158251142927638
# Error:     39.07%
#
# Ford Figo Diesel Titanium:
# Given Value:  6.2
# Predicted Value: 5.507340762225281
# Error:    -11.17%
#
# Hyundai Grand i10 CRDi Sportz Celebration Edition:
# Given Value:  27.5
# Predicted Value: 26.55285929161491
# Error:     -3.44%
#
# Toyota Fortuner 4x2 Manual:
# Given Value:  16.95
# Predicted Value: 17.2934542541805
# Error:      2.03%
#
# Hyundai Verna Transform VTVT:
# Given Value:  12.9
# Predicted Value: 11.009633692481277
# Error:    -14.65%
#
# Honda Jazz 1.2 SV i VTEC:
# Given Value:  65.0
# Predicted Value: 14.215089104478798
# Error:    -78.13%
#
# Audi Q3 35 TDI Quattro Premium Plus:
# Given Value:  21.0
# Predicted Value: 21.61633509995206
# Error:      2.93%
#
# Toyota Corolla Altis 1.8 VL CVT:
# Given Value:  2.5
# Predicted Value: 0.26829856228841464
# Error:    -89.27%
#
# Honda City i-DTEC ZX:
# Given Value:  2.5
# Predicted Value: 3.8676316469830123
# Error:     54.71%
#
# BMW X5 xDrive 30d M Sport:
# Given Value:  34.78
# Predicted Value: 30.614350356430077
# Error:    -11.98%
#
# BMW 3 Series 320d Luxury Line:
# Given Value:  8.0
# Predicted Value: 9.204005804480337
# Error:     15.05%
#
# Tata Indica Vista Quadrajet VX:
# Given Value:  2.85
# Predicted Value: 1.3860547737552267
# Error:    -51.37%
#
# Ford Figo Diesel Celebration Edition:
# Given Value:  5.95
# Predicted Value: 2.2971224531773125
# Error:    -61.39%
#
# Mercedes-Benz New C-Class C 220 CDI Elegance AT:
# Given Value:  5.99
# Predicted Value: 8.972674352230884
# Error:     49.79%
#
# Honda Jazz 1.5 VX i DTEC:
# Given Value:  32.73
# Predicted Value: 31.922878622987263
# Error:     -2.47%
#
# Volkswagen Vento Petrol Highline AT:
# Given Value:  7.5
# Predicted Value: 11.158073543807422
# Error:     48.77%
#
# Maruti Ertiga VDI:
# Given Value:  10.64
# Predicted Value: 12.373227085598787
# Error:     16.29%
#
# Hyundai Grand i10 1.2 Kappa Asta:
# Given Value:  4.25
# Predicted Value: 3.6121914080337767
# Error:    -15.01%
#
# Mercedes-Benz E-Class 2015-2017 E250 CDI Avantgarde:
# Given Value:  3.5
# Predicted Value: 1.9139925975732863
# Error:    -45.31%
#
# Volkswagen Passat Diesel Highline 2.0 TDI:
# Given Value:  15.3
# Predicted Value: 21.067053929743604
# Error:     37.69%
#
# Toyota Fortuner 2.8 4WD MT:
# Given Value:  5.25
# Predicted Value: 4.323879033747821
# Error:    -17.64%
#
# Maruti Swift Dzire VDI:
# Given Value:  1.6
# Predicted Value: -1.5322662276980807
# Error:     -4.23%
#
# Hyundai Grand i10 Asta:
# Given Value:  6.5
# Predicted Value: 6.282530928978681
# Error:     -3.35%
#
# BMW 3 Series 320d Sport:
# Given Value:  2.9
# Predicted Value: 2.2040856052568794
# Error:    -24.00%
#
# Renault Duster 85PS Diesel RxE:
# Given Value:  4.9
# Predicted Value: 4.2518147390189505
# Error:    -13.23%
#
# Tata Indigo LS:
# Given Value:  3.6
# Predicted Value: 1.9179138036058898
# Error:    -46.72%
#
# Ford Ecosport 1.5 Ti VCT MT Titanium:
# Given Value:  27.75
# Predicted Value: 25.627993661094337
# Error:     -7.65%
#
# Maruti Swift Vdi BSIII:
# Given Value:  9.15
# Predicted Value: 11.549892075688579
# Error:     26.23%
#
# Hyundai Xcent 1.2 Kappa Base:
# Given Value:  28.5
# Predicted Value: 28.746430488718577
# Error:      0.86%
#
# Maruti Celerio ZDi:
# Given Value:  13.9
# Predicted Value: 13.215631298212418
# Error:     -4.92%
#
# BMW X1 xDrive 20d xLine:
# Given Value:  4.62
# Predicted Value: 5.679749713133187
# Error:     22.94%
#
# Honda Jazz 1.2 V CVT i VTEC:
# Given Value:  5.99
# Predicted Value: 4.513888858648604
# Error:    -24.64%
#
# BMW X1 sDrive20d:
# Given Value:  13.23
# Predicted Value: 11.808807731743487
# Error:    -10.74%
#
# Hyundai Elantra 2.0 SX Option AT:
# Given Value:  9.85
# Predicted Value: 9.698119229072823
# Error:     -1.54%
#
# Skoda Rapid 1.6 MPI AT Ambition Plus:
# Given Value:  2.85
# Predicted Value: 3.1803704379247213
# Error:     11.59%
#
# Toyota Corolla Altis Diesel D4DG:
# Given Value:  6.35
# Predicted Value: 4.900536030468686
# Error:    -22.83%
#
# Hyundai Creta 1.6 CRDi AT SX Plus:
# Given Value:  3.91
# Predicted Value: 2.905810039088724
# Error:    -25.68%
#
# Hyundai Creta 1.6 SX Plus Dual Tone Petrol:
# Given Value:  3.2
# Predicted Value: 2.6016529344371495
# Error:    -18.70%
#
# Mahindra Xylo E4:
# Given Value:  3.45
# Predicted Value: 5.746497050060165
# Error:     66.57%
#
# Renault Duster 110PS Diesel RxZ Pack:
# Given Value:  7.5
# Predicted Value: 9.28789752511371
# Error:     23.84%
#
# Maruti Ritz LDi:
# Given Value:  38.75
# Predicted Value: 31.760963699311805
# Error:    -18.04%
#
# Renault KWID RXT:
# Given Value:  6.03
# Predicted Value: 9.509434431856205
# Error:     57.70%
#
# Hyundai i20 Magna 1.4 CRDi (Diesel):
# Given Value:  3.47
# Predicted Value: 3.8193767475820612
# Error:     10.07%
#
# Hyundai Verna 1.6 SX VTVT (O):
# Given Value:  7.45
# Predicted Value: 2.775597815164839
# Error:    -62.74%
#
# Mercedes-Benz GL-Class 350 CDI Blue Efficiency:
# Given Value:  3.5
# Predicted Value: -1.593358550241426
# Error:    -54.48%
#
# Hyundai Grand i10 1.2 Kappa Sportz:
# Given Value:  3.25
# Predicted Value: 12.105740894093703
# Error:    272.48%
#
# Ford Figo Diesel ZXI:
# Given Value:  3.45
# Predicted Value: 0.6451590968289231
# Error:    -81.30%
#
# Mahindra Scorpio VLX:
# Given Value:  6.0
# Predicted Value: 8.421544938118391
# Error:     40.36%
#
# Volkswagen Polo Petrol Highline 1.2L:
# Given Value:  4.1
# Predicted Value: 5.037375138386991
# Error:     22.86%
#
# Skoda Superb 2.8 V6 AT:
# Given Value:  20.4
# Predicted Value: 20.00880311386925
# Error:     -1.92%
#
# Hyundai i10 Sportz 1.2:
# Given Value:  3.2
# Predicted Value: 2.369265675558167
# Error:    -25.96%
#
# Ford Aspire Titanium Diesel:
# Given Value:  4.9
# Predicted Value: 4.067658311075336
# Error:    -16.99%
#
# Ford Figo Diesel ZXI:
# Given Value:  5.85
# Predicted Value: 10.564367351621847
# Error:     80.59%
#
# Toyota Innova Crysta 2.4 VX MT:
# Given Value:  1.95
# Predicted Value: -3.959408949525672
# Error:    103.05%
#
# Toyota Etios G Safety:
# Given Value:  15.0
# Predicted Value: 14.228324886965432
# Error:     -5.14%
#
# Volkswagen Polo Petrol Comfortline 1.2L:
# Given Value:  4.85
# Predicted Value: 4.252764522729911
# Error:    -12.31%
#
# Hyundai Grand i10 1.2 Kappa Sportz:
# Given Value:  4.5
# Predicted Value: 3.9401616880539727
# Error:    -12.44%
#
# Hyundai i10 Sportz 1.2:
# Given Value:  3.0
# Predicted Value: 6.35003747216197
# Error:    111.67%
#
# Toyota Fortuner 4x2 AT:
# Given Value:  5.36
# Predicted Value: 4.844143980132071
# Error:     -9.62%
#
# Honda Jazz VX:
# Given Value:  12.5
# Predicted Value: 9.338797603780609
# Error:    -25.29%
#
# Honda Amaze S i-DTEC:
# Given Value:  13.9
# Predicted Value: 21.325461210814048
# Error:     53.42%
#
# Honda Accord VTi-L (AT):
# Given Value:  7.2
# Predicted Value: 9.369178005021753
# Error:     30.13%
#
# Maruti Swift VDI:
# Given Value:  3.75
# Predicted Value: 2.6617211397452287
# Error:    -29.02%
#
# Toyota Innova 2.5 VX (Diesel) 8 Seater:
# Given Value:  2.5
# Predicted Value: 5.090483379315253
# Error:    103.62%
#
# BMW 5 Series 2003-2012 525d:
# Given Value:  26.0
# Predicted Value: 21.933221671897915
# Error:    -15.64%
#
# Honda Jazz 1.5 VX i DTEC:
# Given Value:  1.97
# Predicted Value: -1.4385272759633612
# Error:    -26.98%
#
# Chevrolet Enjoy 1.4 LS 8:
# Given Value:  3.6
# Predicted Value: 2.814372835722782
# Error:    -21.82%
#
# Hyundai Verna CRDi 1.6 SX:
# Given Value:  4.28
# Predicted Value: 5.452923452264279
# Error:     27.40%
#
# Ford Endeavour 3.2 Trend AT 4X4:
# Given Value:  3.8
# Predicted Value: 3.3000730228255657
# Error:    -13.16%
#
# Hyundai EON D Lite Plus:
# Given Value:  16.0
# Predicted Value: 12.663613449125418
# Error:    -20.85%
#
# Volkswagen Polo 1.5 TDI Highline:
# Given Value:  2.25
# Predicted Value: -2.049557133890156
# Error:     -8.91%
#
# Hyundai Verna 1.6 SX CRDi (O):
# Given Value:  8.08
# Predicted Value: 24.634584382668592
# Error:    204.88%
#
# Honda City 1.5 S AT:
# Given Value:  1.5
# Predicted Value: -3.2130871194796367
# Error:    114.21%
#
# Skoda Octavia Elegance 2.0 TDI AT:
# Given Value:  5.0
# Predicted Value: 5.1418632828944055
# Error:      2.84%
#
# Maruti Wagon R LXI BS IV:
# Given Value:  1.25
# Predicted Value: -2.5872194408285303
# Error:    106.98%
#
# Audi A6 3.0 TDI quattro:
# Given Value:  3.74
# Predicted Value: 1.5274154415189614
# Error:    -59.16%
#
# Honda City 1.5 GXI:
# Given Value:  5.98
# Predicted Value: 8.98155111649296
# Error:     50.19%
#
# Honda Amaze SX i-VTEC:
# Given Value:  30.0
# Predicted Value: 42.40895511697081
# Error:     41.36%
#
# Fiat Grande Punto 1.2 Dynamic:
# Given Value:  3.6
# Predicted Value: 4.608035580148316
# Error:     28.00%
#
# Honda Brio S Option MT:
# Given Value:  16.81
# Predicted Value: 16.007277766259882
# Error:     -4.78%
#
# Hyundai Grand i10 1.2 Kappa Asta:
# Given Value:  8.25
# Predicted Value: 9.702856826534765
# Error:     17.61%
#
# Mercedes-Benz S Class 2005 2013 S 500:
# Given Value:  4.12
# Predicted Value: 2.6462231382862482
# Error:    -35.77%
#
# Hyundai Xcent 1.2 Kappa SX:
# Given Value:  8.85
# Predicted Value: 8.6055775504766
# Error:     -2.76%
#
# Skoda Superb Style 1.8 TSI AT:
# Given Value:  3.55
# Predicted Value: 2.6822059318003717
# Error:    -24.44%
#
# Toyota Corolla Altis G HV AT:
# Given Value:  1.5
# Predicted Value: -3.5874421573981436
# Error:    139.16%
#
# Honda Amaze S i-Vtech:
# Given Value:  7.85
# Predicted Value: 6.146799632536694
# Error:    -21.70%
#
# Maruti Vitara Brezza ZDi Plus Dual Tone:
# Given Value:  3.51
# Predicted Value: 3.4367068630157647
# Error:     -2.09%
#
# Hyundai Grand i10 Asta:
# Given Value:  5.5
# Predicted Value: 5.091181691710653
# Error:     -7.43%
#
# Maruti Omni 8 Seater BSIV:
# Given Value:  12.5
# Predicted Value: 10.176603470063455
# Error:    -18.59%
#
# Maruti Ciaz RS ZDi Plus SHVS:
# Given Value:  10.5
# Predicted Value: 11.305813309700374
# Error:      7.67%
#
# Maruti Alto 800 LXI:
# Given Value:  7.75
# Predicted Value: 10.399267030649957
# Error:     34.18%
#
# Mahindra XUV500 W8 2WD:
# Given Value:  17.5
# Predicted Value: 19.075531941928922
# Error:      9.00%
#
# Mahindra XUV500 W10 2WD:
# Given Value:  19.9
# Predicted Value: 25.575750273948508
# Error:     28.52%
#
# Hyundai Creta 1.4 E Plus Diesel:
# Given Value:  7.58
# Predicted Value: 11.401634215744595
# Error:     50.42%
#
# Honda City i DTec V:
# Given Value:  10.75
# Predicted Value: 6.822906122474688
# Error:    -36.53%
#
# Toyota Innova Crysta 2.4 GX MT 8S:
# Given Value:  15.0
# Predicted Value: 18.335405474957398
# Error:     22.24%
#
# Mercedes-Benz B Class B200 CDI:
# Given Value:  4.3
# Predicted Value: 1.6966695630980038
# Error:    -60.54%
#
# Hyundai i20 1.2 Spotz:
# Given Value:  39.47
# Predicted Value: 24.855480112228374
# Error:    -37.03%
#
# Toyota Innova 2.5 V Diesel 8-seater:
# Given Value:  3.25
# Predicted Value: 1.4958768432270002
# Error:    -53.97%
#
# BMW 3 Series 318i Sedan:
# Given Value:  1.0
# Predicted Value: -0.7256793462624636
# Error:    -27.43%
#
# Hyundai i10 Magna:
# Given Value:  14.25
# Predicted Value: 14.079887339292787
# Error:     -1.19%
#
# Audi Q5 30 TDI quattro Premium Plus:
# Given Value:  7.25
# Predicted Value: 8.429165637054766
# Error:     16.26%
#
# Maruti Ritz VXi:
# Given Value:  17.98
# Predicted Value: 20.34997634988889
# Error:     13.18%
#
# Maruti Wagon R VXI:
# Given Value:  3.75
# Predicted Value: 4.177370261134683
# Error:     11.40%
#
# Tata Hexa XT:
# Given Value:  35.0
# Predicted Value: 25.80431892730118
# Error:    -26.27%
#
# Ford EcoSport 1.5 TDCi Trend:
# Given Value:  28.0
# Predicted Value: 33.05566766391825
# Error:     18.06%
#
# BMW X3 xDrive 20d Luxury Line:
# Given Value:  10.2
# Predicted Value: 16.461564779212427
# Error:     61.39%
#
# Volkswagen Vento Diesel Trendline:
# Given Value:  11.25
# Predicted Value: 10.825504068198251
# Error:     -3.77%
#
# BMW 3 Series Luxury Line:
# Given Value:  7.56
# Predicted Value: 9.621840305387122
# Error:     27.27%
#
# Mercedes-Benz M-Class ML 350 CDI:
# Given Value:  9.89
# Predicted Value: 12.236613546193036
# Error:     23.73%
#
# Audi A4 New 2.0 TDI Multitronic:
# Given Value:  14.0
# Predicted Value: 17.82817406361224
# Error:     27.34%
#
# Toyota Innova 2.5 G (Diesel) 7 Seater:
# Given Value:  8.6
# Predicted Value: 9.866039845578136
# Error:     14.72%
#
# Honda Jazz 1.2 SV i VTEC:
# Given Value:  6.3
# Predicted Value: 10.206332844534352
# Error:     62.01%
#
# Maruti Baleno Alpha Automatic:
# Given Value:  4.25
# Predicted Value: 3.117515913380207
# Error:    -26.65%
#
# Audi A4 2.0 TDI:
# Given Value:  2.25
# Predicted Value: 0.8489009683126536
# Error:    -62.27%
#
# ...
#
# Maruti Alto 800 LXI:
# Given Value:  29.0
# Predicted Value: 28.523538411420052
# Error:     -1.64%
#
# Honda City V AT:
# Given Value:  34.0
# Predicted Value: 30.58611547719803
# Error:    -10.04%
#
# Mahindra Bolero SLE:
# Given Value:  7.25
# Predicted Value: 7.097407803394863
# Error:     -2.10%
#
# Maruti Dzire AMT ZDI Plus:
# Given Value:  28.0
# Predicted Value: 25.884252825859388
# Error:     -7.56%
#
# Volkswagen Ameo 1.2 MPI Comfortline:
# Given Value:  5.84
# Predicted Value: 9.105845045085697
# Error:     55.92%
#
# Honda Jazz VX:
# Given Value:  3.65
# Predicted Value: 2.1252166789946845
# Error:    -41.77%
#
# Maruti Baleno Zeta 1.2:
# Given Value:  11.65
# Predicted Value: 14.625565849241992
# Error:     25.54%
#
# Mahindra Xylo D2 BSIV:
# Given Value:  17.5
# Predicted Value: 20.0976395206733
# Error:     14.84%
#
# Ford Figo 2015-2019 1.5D Trend MT:
# Given Value:  28.03
# Predicted Value: 27.02624212666695
# Error:     -3.58%
#
# Nissan Micra Diesel:
# Given Value:  6.12
# Predicted Value: 4.373714612501126
# Error:    -28.53%
#
# Hyundai Santro GLS I - Euro I:
# Given Value:  6.75
# Predicted Value: 6.106525095632369
# Error:     -9.53%
#
# Skoda Superb Elegance 1.8 TSI AT:
# Given Value:  4.75
# Predicted Value: 6.4365312292041645
# Error:     35.51%
#
# Maruti Ciaz VXi Plus:
# Given Value:  2.85
# Predicted Value: 1.1325584624264806
# Error:    -60.26%
#
# Volkswagen Polo 1.5 TDI Highline:
# Given Value:  23.5
# Predicted Value: 24.54401720448533
# Error:      4.44%
#
# Mercedes-Benz E-Class 2009-2013 E250 CDI Elegance:
# Given Value:  5.64
# Predicted Value: 6.07589333796443
# Error:      7.73%
#
# Mercedes-Benz E-Class 2009-2013 E250 CDI Elegance:
# Given Value:  25.0
# Predicted Value: 31.01810446022633
# Error:     24.07%
#
# Renault Duster 110PS Diesel RxZ Pack:
# Given Value:  7.64
# Predicted Value: 6.672164542870674
# Error:    -12.67%
#
# Audi A4 35 TDI Premium Sport:
# Given Value:  5.67
# Predicted Value: 7.8768299210326065
# Error:     38.92%
#
# Volkswagen Ameo 1.2 MPI Comfortline:
# Given Value:  1.5
# Predicted Value: 1.8070545344058688
# Error:     20.47%
#
# Hyundai i10 Sportz 1.2:
# Given Value:  12.75
# Predicted Value: 20.820049038145616
# Error:     63.29%
#
# Ford Ecosport Signature Edition Diesel:
# Given Value:  26.0
# Predicted Value: 25.952389788601113
# Error:     -0.18%
#
# BMW 5 Series 520d Luxury Line:
# Given Value:  16.46
# Predicted Value: 15.624324930269939
# Error:     -5.08%
#
# Audi Q3 35 TDI Quattro Premium Plus:
# Given Value:  9.45
# Predicted Value: 8.84051603721184
# Error:     -6.45%
#
# Mahindra Bolero VLX CRDe:
# Given Value:  11.0
# Predicted Value: 13.611696670748366
# Error:     23.74%
#
# Maruti Baleno Alpha 1.3:
# Given Value:  6.7
# Predicted Value: 9.17039550000746
# Error:     36.87%
#
# Hyundai i20 Sportz AT 1.4:
# Given Value:  5.0
# Predicted Value: 5.964563814654789
# Error:     19.29%
#
# Hyundai Grand i10 Era:
# Given Value:  2.9
# Predicted Value: 4.111392032672855
# Error:     41.77%
#
# Toyota Etios Liva GD:
# Given Value:  2.69
# Predicted Value: 2.950918228001189
# Error:      9.70%
#
# Audi Q3 2012-2015 35 TDI Quattro Premium Plus:
# Given Value:  28.88
# Predicted Value: 24.132935687063046
# Error:    -16.44%
#
# Hyundai Grand i10 Sportz:
# Given Value:  18.12
# Predicted Value: 25.172052200460328
# Error:     38.92%
#
# Mercedes-Benz S Class 2005 2013 S 350 CDI:
# Given Value:  6.75
# Predicted Value: 12.391957792041069
# Error:     83.58%
#
# Maruti Ertiga VDI:
# Given Value:  6.63
# Predicted Value: 6.77583050973494
# Error:      2.20%
#
# Renault Duster 85PS Diesel RxL:
# Given Value:  2.75
# Predicted Value: -1.3106893277079124
# Error:    -52.34%
#
# Chevrolet Optra 1.6 LS:
# Given Value:  9.25
# Predicted Value: 22.765560748899254
# Error:    146.11%
#
# BMW 3 Series 320d Highline:
# Given Value:  1.75
# Predicted Value: -1.1899344045742666
# Error:    -32.00%
#
# Mercedes-Benz CLA 200 Sport Edition:
# Given Value:  13.5
# Predicted Value: 13.878702268852999
# Error:      2.81%
#
# Mahindra XUV500 AT W10 FWD:
# Given Value:  12.46
# Predicted Value: 12.349781481078924
# Error:     -0.88%
#
# Volkswagen Vento 1.5 TDI Highline AT:
# Given Value:  5.49
# Predicted Value: 5.8984705092664305
# Error:      7.44%
#
# Hyundai Santro Xing XL eRLX Euro III:
# Given Value:  40.0
# Predicted Value: 42.32290415747524
# Error:      5.81%
#
# Toyota Fortuner 3.0 Diesel:
# Given Value:  3.1
# Predicted Value: 3.431943108477876
# Error:     10.71%
#
# Ford Figo Aspire 1.2 Ti-VCT Trend:
# Given Value:  9.92
# Predicted Value: 18.911963390890964
# Error:     90.64%
#
# Volkswagen Vento Diesel Highline:
# Given Value:  4.4
# Predicted Value: 5.0168235101954295
# Error:     14.02%
#
# Maruti Swift Dzire Tour LDI:
# Given Value:  5.8
# Predicted Value: 6.045394465265541
# Error:      4.23%
#
# Maruti Swift Dzire LDI:
# Given Value:  32.5
# Predicted Value: 22.489670672066303
# Error:    -30.80%
#
# Ford Endeavour 3.2 Titanium AT 4X4:
# Given Value:  2.23
# Predicted Value: -2.1305500299211193
# Error:     -4.46%
#
# Mercedes-Benz New C-Class C 220d Avantgarde Edition C:
# Given Value:  4.75
# Predicted Value: 3.9147749881311498
# Error:    -17.58%
#
# Skoda Superb 2.5 TDi AT:
# Given Value:  27.0
# Predicted Value: 25.546968361808673
# Error:     -5.38%
#
# Ford Ecosport 1.5 DV5 MT Titanium Optional:
# Given Value:  2.02
# Predicted Value: 62.3751137900866
# Error:   2987.88%
#
# Hyundai i20 2015-2017 1.2 Asta:
# Given Value:  12.5
# Predicted Value: 16.704421773879428
# Error:     33.64%
#
# Mercedes-Benz New C-Class C 220 CDI Elegance AT:
# Given Value:  3.99
# Predicted Value: 3.2985465113837042
# Error:    -17.33%
#
# Maruti Wagon R LXI BSIII:
# Given Value:  6.0
# Predicted Value: 13.50875606582819
# Error:    125.15%
#
# Toyota Fortuner 4x2 Manual:
# Given Value:  6.3
# Predicted Value: 6.460259082346622
# Error:      2.54%
#
# Renault Duster 110PS Diesel RxZ AMT:
# Given Value:  6.1
# Predicted Value: 4.527678209212727
# Error:    -25.78%
#
# Ford Ecosport 1.5 DV5 MT Trend:
# Given Value:  2.8
# Predicted Value: 3.1804530235360584
# Error:     13.59%
#
# Land Rover Range Rover Sport 2005 2012 HSE:
# Given Value:  4.8
# Predicted Value: 5.432863691191028
# Error:     13.18%
#
# Mahindra Verito 1.5 D4 BSIV:
# Given Value:  3.35
# Predicted Value: 1.677568871234854
# Error:    -49.92%
#
# BMW 3 Series 320d:
# Given Value:  8.5
# Predicted Value: 8.413679890905797
# Error:     -1.02%
#
# Hyundai Grand i10 1.2 Kappa Asta:
# Given Value:  4.75
# Predicted Value: 5.593317106498431
# Error:     17.75%
#
# Hyundai Xcent 1.2 Kappa AT SX Option:
# Given Value:  13.0
# Predicted Value: 17.751063138112944
# Error:     36.55%
#
# Audi Q5 2.0 TDI Premium Plus:
# Given Value:  36.75
# Predicted Value: 46.00450796006067
# Error:     25.18%
#
# Hyundai i20 Magna:
# Given Value:  3.67
# Predicted Value: 1.4073999930033292
# Error:    -61.65%
#
# Honda City i DTEC SV:
# Given Value:  2.6
# Predicted Value: 3.8857315117891265
# Error:     49.45%
#
# BMW 3 Series Luxury Line:
# Given Value:  6.25
# Predicted Value: 8.82006210109918
# Error:     41.12%
#
# Porsche Cayenne Base:
# Given Value:  4.11
# Predicted Value: 3.398247293112745
# Error:    -17.32%
#
# Ford Fiesta 1.4 SXi TDCi:
# Given Value:  7.8
# Predicted Value: 11.394348167638283
# Error:     46.08%
#
# BMW 5 Series 523i Sedan:
# Given Value:  8.75
# Predicted Value: 5.543486074828868
# Error:    -36.65%
#
# Maruti Swift Dzire VXI:
# Given Value:  18.25
# Predicted Value: 16.84317352318028
# Error:     -7.71%
#
# Hyundai Sonata Transform 2.4 GDi AT:
# Given Value:  1.55
# Predicted Value: -1.8145603896265214
# Error:     17.07%
#
# Hyundai i20 Sportz 1.2:
# Given Value:  10.25
# Predicted Value: 12.122126433899416
# Error:     18.26%
#
# Maruti Ciaz AT ZXi:
# Given Value:  26.0
# Predicted Value: 24.075976208039727
# Error:     -7.40%
#
# Maruti Wagon R VXI:
# Given Value:  3.4
# Predicted Value: 0.40270666862427085
# Error:    -88.16%
#
# Maruti Swift Dzire 1.2 Vxi BSIV:
# Given Value:  1.8
# Predicted Value: -4.002339338026111
# Error:    122.35%
#
# Honda City 1.5 V MT:
# Given Value:  12.5
# Predicted Value: 23.579332542661408
# Error:     88.63%
#
# Mahindra XUV500 W8 4WD:
# Given Value:  4.5
# Predicted Value: 3.52944483910494
# Error:    -21.57%
#
# Hyundai Verna 1.6 SX:
# Given Value:  9.0
# Predicted Value: 10.174564708644178
# Error:     13.05%
#
# Mercedes-Benz A Class A180 CDI:
# Given Value:  10.5
# Predicted Value: 14.07459954407619
# Error:     34.04%
#
# Land Rover Discovery SE 3.0 TD6:
# Given Value:  4.23
# Predicted Value: 6.18928353431116
# Error:     46.32%
#
# Hyundai i20 Magna Optional 1.2:
# Given Value:  3.9
# Predicted Value: 2.535948696839017
# Error:    -34.98%
#
# Honda Civic 2006-2010 1.8 S AT:
# Given Value:  5.35
# Predicted Value: 4.760915768507109
# Error:    -11.01%
#
# Toyota Etios Cross 1.4 GD:
# Given Value:  43.74
# Predicted Value: 28.13026608825956
# Error:    -35.69%
#
# Hyundai i20 Asta 1.4 CRDi:
# Given Value:  5.4
# Predicted Value: 7.155633063862936
# Error:     32.51%
#
# Hyundai i20 1.2 Spotz:
# Given Value:  2.85
# Predicted Value: -0.32464989912457654
# Error:    -88.61%
#
# Skoda Octavia Ambition 1.4 TSI MT:
# Given Value:  5.8
# Predicted Value: 7.557208100885671
# Error:     30.30%
#
# Toyota Fortuner 4x2 AT:
# Given Value:  2.2
# Predicted Value: -2.576114182605938
# Error:     17.10%
#
# Ford Fiesta 1.4 TDCi EXI:
# Given Value:  12.0
# Predicted Value: 14.222580460500662
# Error:     18.52%
#
# Toyota Innova 2.5 G (Diesel) 7 Seater:
# Given Value:  30.0
# Predicted Value: 27.871805780184474
# Error:     -7.09%
#
# Porsche Cayman 2009-2012 S tiptronic:
# Given Value:  3.6
# Predicted Value: 6.583431427493629
# Error:     82.87%
#
# Mercedes-Benz GLA Class 200 CDI:
# Given Value:  3.7
# Predicted Value: 3.7957203670280943
# Error:      2.59%
#
# Hyundai i20 1.2 Magna:
# Given Value:  11.0
# Predicted Value: 9.753889520094116
# Error:    -11.33%
#
# Maruti Swift VDI BSIV:
# Given Value:  14.5
# Predicted Value: 16.000596530227895
# Error:     10.35%
#
# Maruti A-Star Vxi:
# Given Value:  7.0
# Predicted Value: 6.402882572922018
# Error:     -8.53%
#
# Mercedes-Benz E-Class 2009-2013 E250 CDI Blue Efficiency:
# Given Value:  26.5
# Predicted Value: 27.277136327556203
# Error:      2.93%
#
# Honda Amaze S Petrol:
# Given Value:  7.87
# Predicted Value: 8.918943562259738
# Error:     13.33%
#
# Maruti Vitara Brezza ZDi Plus:
# Given Value:  11.75
# Predicted Value: 10.770087066433229
# Error:     -8.34%
#
# Mahindra Ssangyong Rexton RX7:
# Given Value:  3.0
# Predicted Value: 6.91030835254844
# Error:    130.34%
#
# Hyundai EON Magna Plus:
# Given Value:  8.61
# Predicted Value: 12.746112458341273
# Error:     48.04%
#
# Honda Amaze S i-Vtech:
# Given Value:  2.45
# Predicted Value: 8.604075116608774
# Error:    251.19%
#
# Volkswagen Polo 1.2 MPI Highline:
# Given Value:  6.1
# Predicted Value: 8.090573386753526
# Error:     32.63%
#
# Audi Q5 30 TDI quattro Premium:
# Given Value:  2.65
# Predicted Value: 3.2418322819944896
# Error:     22.33%
#
# Maruti Swift Dzire VDi:
# Given Value:  6.0
# Predicted Value: 6.486136143726351
# Error:      8.10%
#
# Hyundai i10 Sportz:
# Given Value:  5.2
# Predicted Value: 5.448719307122734
# Error:      4.78%
#
# Toyota Etios GD:
# Given Value:  3.15
# Predicted Value: 0.743077553361621
# Error:    -76.41%
#
# Hyundai i10 Era 1.1:
# Given Value:  6.5
# Predicted Value: 5.5622624648932835
# Error:    -14.43%
#
# Audi A4 2.0 TFSI:
# Given Value:  3.5
# Predicted Value: 1.6530287692769559
# Error:    -52.77%
#
# Mercedes-Benz M-Class ML 250 CDI:
# Given Value:  2.01
# Predicted Value: -2.729846189356289
# Error:     35.81%
#
# Tata New Safari DICOR 2.2 EX 4x4:
# Given Value:  2.65
# Predicted Value: 2.990619605969963
# Error:     12.85%
#
# Hyundai Xcent 1.1 CRDi Base:
# Given Value:  27.0
# Predicted Value: 39.024481576716894
# Error:     44.54%
#
# Mitsubishi Pajero 2.8 SFX:
# Given Value:  9.5
# Predicted Value: 15.434799963014495
# Error:     62.47%
#
# Hyundai Santa Fe 4WD AT:
# Given Value:  11.97
# Predicted Value: 12.672322296969009
# Error:      5.87%
#
# Maruti Ertiga VDI:
# Given Value:  6.46
# Predicted Value: 10.083407901908716
# Error:     56.09%
#
# Jaguar XF 2.2 Litre Luxury:
# Given Value:  2.25
# Predicted Value: 1.1393363231237537
# Error:    -49.36%
#
# Honda City i VTEC V:
# Given Value:  7.25
# Predicted Value: 7.980259896192996
# Error:     10.07%
#
# Toyota Innova 2.5 VX 7 STR BSIV:
# Given Value:  5.5
# Predicted Value: 5.442048959223437
# Error:     -1.05%
#
# Maruti Swift Dzire LDI:
# Given Value:  3.0
# Predicted Value: 9.603490090939854
# Error:    220.12%
#
# Maruti Baleno RS Petrol:
# Given Value:  4.25
# Predicted Value: 6.806983453578277
# Error:     60.16%
#
# Toyota Corolla H4:
# Given Value:  3.25
# Predicted Value: 4.269148221360338
# Error:     31.36%
#
# Honda Amaze E i-Dtech:
# Given Value:  12.69
# Predicted Value: 9.473947313978025
# Error:    -25.34%
#
# Maruti Alto K10 LXI:
# Given Value:  6.27
# Predicted Value: 9.584058464370939
# Error:     52.86%
#
# Honda City V MT:
# Given Value:  31.0
# Predicted Value: 28.12596588180176
# Error:     -9.27%
#
# Maruti Swift RS VDI:
# Given Value:  21.0
# Predicted Value: 23.346093167318962
# Error:     11.17%
#
# Honda Amaze S Petrol:
# Given Value:  9.45
# Predicted Value: 8.6439915328274
# Error:     -8.53%
#
# Maruti Baleno Alpha Diesel:
# Given Value:  11.88
# Predicted Value: 13.811728158838783
# Error:     16.26%
#
# Hyundai Grand i10 CRDi Sportz:
# Given Value:  8.9
# Predicted Value: 9.385753212274691
# Error:      5.46%
#
# Maruti Alto 800 2016-2019 LXI:
# Given Value:  6.21
# Predicted Value: 5.121956511071752
# Error:    -17.52%
#
# Mahindra Xylo E2:
# Given Value:  8.4
# Predicted Value: 12.052157344153425
# Error:     43.48%
#
# Land Rover Range Rover 2.2L Pure:
# Given Value:  8.0
# Predicted Value: 7.774501524755194
# Error:     -2.82%
#
# Audi A4 1.8 TFSI:
# Given Value:  15.25
# Predicted Value: 20.394572426918582
# Error:     33.73%
#
# Honda City i-VTEC CVT VX:
# Given Value:  7.52
# Predicted Value: 7.615731920871893
# Error:      1.27%
#
# Ford Figo Aspire 1.2 Ti-VCT Titanium:
# Given Value:  4.92
# Predicted Value: 5.182804433612595
# Error:      5.34%
#
# Fiat Linea Emotion Pack (Diesel):
# Given Value:  2.0
# Predicted Value: -1.1928798869288961
# Error:    -40.36%
#
# Maruti Swift Dzire VDI:
# Given Value:  4.9
# Predicted Value: 7.285685453682264
# Error:     48.69%
#
# Chevrolet Enjoy 1.3 TCDi LTZ 8:
# Given Value:  2.0
# Predicted Value: 2.005191788605962
# Error:      0.26%
#
# Ford Endeavour 4x2 XLT Limited Edition:
# Given Value:  56.0
# Predicted Value: 34.72303098146967
# Error:    -37.99%
#
# Skoda Rapid 1.5 TDI AT Elegance:
# Given Value:  6.61
# Predicted Value: 5.929019239645326
# Error:    -10.30%
#
# Hyundai EON Era:
# Given Value:  2.2
# Predicted Value: 6.264846353505315
# Error:    184.77%
#
# Honda City i-VTEC CVT ZX:
# Given Value:  3.95
# Predicted Value: 2.9491925850286407
# Error:    -25.34%
#
# Hyundai i20 1.2 Magna Executive:
# Given Value:  12.5
# Predicted Value: 15.797212349005305
# Error:     26.38%
#
# Jaguar XF 2.2 Litre Luxury:
# Given Value:  6.0
# Predicted Value: 3.1989026601705657
# Error:    -46.68%
#
# Audi Q3 2.0 TDI Quattro:
# Given Value:  2.25
# Predicted Value: -0.33690777927281346
# Error:    -85.03%
#
# Toyota Innova 2.5 G (Diesel) 7 Seater BS IV:
# Given Value:  3.75
# Predicted Value: 4.687872477375122
# Error:     25.01%
#
# Hyundai Verna VTVT 1.6 SX Option:
# Given Value:  7.48
# Predicted Value: 8.516399048209959
# Error:     13.86%
#
# Honda WRV i-VTEC VX:
# Given Value:  8.9
# Predicted Value: 9.562366606195395
# Error:      7.44%
#
# Maruti Swift Dzire ZXI:
# Given Value:  5.21
# Predicted Value: 8.173304823889046
# Error:     56.88%
#
# Maruti Swift DDiS VDI:
# Given Value:  8.95
# Predicted Value: 19.113974141122416
# Error:    113.56%
#
# Maruti Vitara Brezza ZDi:
# Given Value:  32.64
# Predicted Value: 27.679495670884602
# Error:    -15.20%
#
# Audi Q3 2.0 TDI Quattro:
# Given Value:  4.5
# Predicted Value: 4.023035152704212
# Error:    -10.60%
#
# Ford EcoSport 1.5 TDCi Titanium:
# Given Value:  3.5
# Predicted Value: 3.4561902248734064
# Error:     -1.25%
#
# Honda Brio S MT:
# Given Value:  22.99
# Predicted Value: 25.010407245275665
# Error:      8.79%
#
# Maruti A-Star Vxi:
# Given Value:  7.1
# Predicted Value: 7.240939986086925
# Error:      1.99%
#
# Renault Duster Petrol RxL:
# Given Value:  3.5
# Predicted Value: 4.791612319077417
# Error:     36.90%
#
# Hyundai Accent GLS:
# Given Value:  2.21
# Predicted Value: 0.4654195509436221
# Error:    -78.94%
#
# Mercedes-Benz GL-Class 350 CDI Blue Efficiency:
# Given Value:  2.6
# Predicted Value: 0.7243396809728218
# Error:    -72.14%
#
# Maruti Swift Dzire ZDI:
# Given Value:  6.8
# Predicted Value: 6.558968977475439
# Error:     -3.54%
#
# Tata Indica V2 eLS:
# Given Value:  0.8
# Predicted Value: -0.78970117287205
# Error:     -1.29%
#
# Maruti Swift Dzire VDI:
# Given Value:  8.27
# Predicted Value: 10.166241267204022
# Error:     22.93%
#
# Audi A4 2.0 TDI Multitronic:
# Given Value:  6.0
# Predicted Value: 7.04250687506322
# Error:     17.38%
#
# Maruti Ertiga VDI:
# Given Value:  9.51
# Predicted Value: 10.44021420364299
# Error:      9.78%

# %% [markdown]
# ## Step 5: Graph the generated results.

# %%
plt.rcParams['figure.figsize'] = [16, 16]
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
ax2.plot(range(0, len(hist)), hist)     #plots the cost function v/s iterations
ax1.scatter(range(0, len(predictions)),predictions, c='r')  #plots the predicted values in red
ax1.scatter(range(0, len(y_test)),y_test, c='g')        #plots the actual values in green
ax1.grid()
ax3.plot(range(0, len(errs)), [err[0] for err in errs])
plt.suptitle("The first graph represents predicted values (red), real values (green),\nThe second graph represents the cost function (y) v/s iterations (x).\nThe third graph represents Mean squared error (y) v/s iterations (x)")
plt.show()

# %% [markdown]
# ## Conclusion:
#
# All features provided in the training sets have been incorporated into this model to increase its accuracy.
# I have implemented one hot encoding using Pandas for characterising the brands, years and locations of the vehicles and have fit them into the model.
# I have used string methods to convert certain numerical values into their corresponding numbers, and also to remove any training example with "null".
# Further, I have used z-score normalisation to ensure all features are fairly evaluated.
#
# I have plotted the graph for cost function and mean square error v/s iterations. Error values (MSE, RMSE, R2) are also printed to the terminal after every 100 iterations. The final error after the model has been trained has also been printed.
#
# After the model is trained, I have displayed the predicted weights and bias of the model for each feature column.
# I have displayed the predicted and real price for every valid testing example in Test.csv, along with their corresponding error.
# I have also graphed these values.
#
# The multiple linear regression model thus generated provides a significant level of accuracy and can be use to efficiently predict the price of a car.
# The MSE, RMSE and R2 scores appear to be well within the acceptable bounds of accuracy.
